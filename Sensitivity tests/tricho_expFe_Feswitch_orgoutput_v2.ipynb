# %% [markdown]
# # Proteome allocation model for Trichodesmium

# %% [markdown]
# ## Parameters

# %%
# Maximum turnover rates for all reactions (# molecules per protein per minute)

kref = Dict(
#"exp" => 120.0,                 # C/N exporters, molecules of C and N org/min
"trn" => 120.0,                  # N transporters, atoms of N/min
"trnh4" => 120.0,                # NH4 transporters, atoms of N/min
"trdop" => 120.0,                # DOP transporters, atoms of P/min
"trpo4" => 120.0,                # PO4 transporters, atoms of P/min
"trsFe" => 120.0,                # siderophore-bound Fe transporters, atoms of Fe/min
#"trfFe" => 60.0,                # not siderophore-bound Fe transporters, atoms of Fe/min
"din" => 2662.0,                 # DIN proteins, atoms of N/min
"ri" => 957.0,                   # ribosomes, molecules of aa/min
"lb" => 120.0,                   # lipid synthesis, atoms of C/min
"p" => 7800.0,                   # photosystems, photons/min
"ru" => 170.6,                   # rubisco, atoms of C/min
#"ld" => 120.0,                  # lipid degradation, atoms of C/min
"gl" => 120.0,                   # glycolysis, atoms of C/min
"re" => 1000.0,                  # repair proteins, atoms of C/min
"d" => 1000.0,                   # heat damage, molecules of photosystem/min
"nt" => 1061.0,                  # nitrogenase, atoms of N/min
"sFe" => 69.2,                   # Siderophore-bound Fe(III) reduction (rate-limiting step), atoms of Fe/min
"fFe" => 151.3,                  # Other Fe(III) reduction (rate-limiting step), atoms of Fe/min 
"nh4" => 88.8,                   # NH4 (glutamate synthetase turnover rate), molecules of NH4/min
"dop" => 954.06,                 # DOP (25% phosphonate dehydrogenase, 75% AP), molecules of DOP/min
"org" => 60,                    # synthesis of organic molecules, organic molecules/min
) 

# Half-saturation constants for all reactions

K = Dict(
"exp" => 1,                      # exporters, uM C/N org molecules
"corg" => 10^4,                  # incorporation of internal carbon by synthesis of organic compounds for export, atoms of C/ um3
"norg" => 10^4,                  # incorporation of internal nitrogen by synthesis of organic compounds for export, atoms of N/ um3
"trn" => 5,                      # DIN transporters, uM DIN. This affects A LOT the range of DIN concentrations for which nitrogenase operates
"trdop" => 1.0,                  # DOP transporters, uM DOP
"trfFe" => 1.0,                  # non siderophore-bound iron transporters, pM Fe
"ic" => 10^5,                    # incorporation of internal carbon by ribosomes, atoms of C/ um3
"in" => 10^4,                    # incorporation of internal nitrogen by ribosomes, atoms of N/ um3
"ntfe" => 10^3,                  # incorporation of internal iron by nitrogenase, atoms of Fe/ um3
"ntn" => 10^4,                   # incorporation of N2 by nitrogenase, atoms of N/um3. Assumed. Doesn't change output that much
"lb" => 10^4,                    # lipid synthesis, atoms of C/um3
"p" => 1.0,                      # photosystems, photons/um3
"pfe" => 10^2,                   # incorporation of internal iron by photosystems, atoms of Fe/um3
"ru" => 1.0,                     # rubisco, uM DIC
#"ld" => 10^4,                   # lipid degradation, atoms of C/um3
"gl" => 10^4,                    # glycolysis, atoms of C/um3
"re" => 10^4,                    # repair proteins, atoms of C/um3
"d" => 10^4,                     # heat damage, atoms of C/um3
"sFe" => 1.0,                    # Siderophore-bound Fe(III) reduction, pM Siderophore-bound Fe
"fFe" => 1.0,                    # Other Fe(III) reduction, pM other Fe
"nh4" => 1.0,                    # NH4 processing, uM NH4
"dop" => 1.0,                    # DOP processing, uM DOP
"trpo4" => 1.0,                  # PO4 processing, uM PO4
)

# Space and density constraints

s_trn = 1.26e-5                  # um2, specific surface area of membrane transporter molecules
Vnt = 3.7e-7                     # um3, volume / nitrogenase
s_lm = 0.5e-6                    # um2, specific surface area of membrane lipid molecules
#clm = 1.17e6                    # number of membrane lipids / um3
Mmax = 0.00045                   # unitless, maximum membrane transporter to lipid ratio
Mmin = 3e-5                      # unitless, minimum membrane transporter to lipid ratio
Vp = 3e-5                        # um3, volume / photosystem
Vli = 1.5e-9                     # um3, volume / lipid droplet
#Dmax = 270/1e15*(6.02e23)/9     # Da/um3, maximum density of the cell
Dmax = 6.14e11                   # Da/um3, maximum density of the cell
ctag_max = 2e7                   # maximum number of lipid molecules / um3 
ctag_min = 200                   # minimum number of lipid molecules / um3
β = 6                            # volume to surface area ratio of a Trichodesmium cell. Max is 40
flmp = 0.554                     # Fraction of membrane lipids that are phospholipids

# Temperature effects

Ttest = 273.0 .+ [3.0:1.0:45.0;] # K, temperature regime
Tmin = minimum(Ttest)            # K, minimum temperature
Tmax = maximum(Ttest)            # K, maximal temperature
Ea = 0.5                         # eV, activation energy  Maranon et al 2018; Barton et al 2020
Ed = 1.5                         # eV, deactivation energy
Etr  = Ea/2                      # eV, activation energy nutrient diffusion
R    = 8.62*10^-5                # eV/K, Boltzmann's constant
Tref = 20+273.0                  # K, reference temperature
Td   = 43+273.0                  # K, critical high temperature

# Molecular weights

ηaa = 110                        # Da / amino acid
ηp  = 12739*ηaa                  # Da / molecule of photosystem
ηtrn = 754*ηaa                   # Da / molecule of N transporter 
ηtrnh4 = 488*ηaa                 # Da / molecule of NH4 transporter 
ηtrsFe = 1665*ηaa                # Da / molecule of siderophore-bound iron transporter 
ηtrfFe = 1333*ηaa                # Da / molecule of other iron transporter 
ηdin = 1989*ηaa                  # Da / molecule of other DIN proteins
ηru = 3110*ηaa                   # Da / molecule of rubisco
ηri = 19323*ηaa                  # Da / molecule of ribosome
ηlb = 13742*ηaa                  # Da / molecule of lipid synthesis pathway proteins
ηgl = 4112*ηaa                   # Da / molecule of glycolysis pathway proteins
#ηld = 5128*ηaa                  # Da / molecule of lipid degradation pathway proteins
ηre = 6350*ηaa                   # Da / molecule of repair proteins
ηnt = 7024*ηaa                   # Da / molecule of nitrogenase
ηsFe = 2849*ηaa                  # Da / molecule of siderophore-bound iron processing proteins
ηfFe = 3107*ηaa                  # Da / molecule of other iron processing proteins
ηnh4 = 2515*ηaa                  # Da / molecule of NH4 processing proteins
ηdop = 728*ηaa                   # Da / molecule of DOP processing proteins
ηtrdop = 1432*ηaa                # Da / molecule of DOP transporter 
ηtrpo4 = 1272*ηaa                # Da / molecule of PO4 transporter 
ηexp = 2057*ηaa                  # Da / molecule of exporter
ηorg = 47*ηaa                    # Da / molecule of polysaccharide biosynthesis proteins
ηot = 1455391*ηaa                # Da / molecule of other proteome
ηin = 14                         # Da / nitrogen atom
ηic = 12                         # Da / carbon atom
ηip = 31                         # Da / phosphorus atom
ηife = 56                        # Da / iron atom
ηgu = 180                        # 180 Da; 6C glucose
ηli = 800                        # 800 Da; 16C TAG
cot = Dmax/4.9/110/(ηot/ηaa)     # molecules of other proteome / um3

# Carbon, Nitrogen, Iron, and Phosphorus quotas

Qpt = 0.20                       # Nitrogen to Carbon ratio of proteins
Qp  = 0.10                       # Nitrogen to Carbon ratio of photosystems
Qri = 0.33                       # Nitrogen to Carbon ratio of ribosomes
Qother = 0.20                    # Nitrogen to Carbon ratio of other proteins not simulated here
Fpt = 0.000158*0.11              # Iron to Carbon ratio of proteins
Fp  = 0.000158*0.33              # Iron to Carbon ratio of photosystems
Fnt = 0.000158*0.46              # Iron to Carbon ratio of nitrogenase
ηlic = 16                        # atoms of C/ molecule of lipid
ηguc = 6                         # atoms of C/ molecule of glucose
ηaac = 5                         # atoms of C/ molecule of amino acid
ηatpp = 3                         # atoms of P/ molecule of ATP
ηrup = 2                         # atoms of P/ rubisco molecule
ηglp = 2                         # atoms of P/ glycolysis pathway proteins
ηntaafe = 7/7024                 # atoms of Fe/aa in nitrogenase
ηpaafe = 15/12739                # atoms of Fe/aa in photosystem
ηlip = 1/39                      # atoms of P/ atom of C in phospholipid
#atp = 6.02e5                    # molecules of ATP/um3 1-5 mM E. coli = 6.02e5-3.01e6

# Energy conversion factors

e_p  = 1.0                       # ATP / photon absorbed
e_ru = 10                        # ATP / carbon
e_trn = 1.0                      # ATP / nitrogen from DIN transported
e_trnh4 = 0.0                    # ATP / nitrogen from NH4 transported
e_trpo4 = 1.0                    # ATP / nitrogen from PO4 transported
e_trdop = 2.0                    # ATP / DOP transported
e_sfe = 8.8                      # ATP / siderophore-bound Fe atom processed
e_ffe = 4.6                      # ATP / other Fe atom processed
e_trsfe = 0.0                    # ATP / siderophore-bound Fe transported
e_trffe = 1.0                    # ATP / other Fe transported
e_ri = 3+9*5                     # ATP / amino acid
e_lb = 3.9                       # ATP / carbon
e_u  = 9e7/ctag_max              # ATP / damaged photosystem 
e_re = 4.5                       # ATP / photosystem
ep_gl = 5.0                      # ATP produced / carbon in glycolysis
ec_gl = 2.0                      # ATP consumed / carbon in glycolysis
#e_ld = 6.6                      # ATP / carbon
e_nt = 8                         # ATP / N atom fixed by nitrogenase
e_din = 5.2                      # ATP / N atom from reduced DIN not including transport
e_nh4 = 3.6                      # ATP / N atom from NH4
e_dop = 0                        # ATP / P atom from DOP
e_exp = 1                        # ATP / C and N org molecule transported

fdr = 0.4                     # fraction of respiration that happens in the dark 
td = 12*60                       # minutes, dark period (12 hours)

#cip = gs_cip
#cic = gs_cic
#cin = gs_cin
#cife = gs_cife
# Out:
# 720

# %% [markdown]
# ## Model

# %% [markdown]
# The model assumes that a cell is growing exponentially at the highest growth rate possible. For each macromolecule in the cell (c), the sum of the rates (v) of all synthesis processes minus the sum of the rates of all degradation processes is balanced by the cellular growth rate μ:
#
# $$
# \frac{dc}{dt} = \sum v_{synthesis} - \sum v_{degradation} - \mu c =0
#
# $$

# %%
# Load packages
using Ipopt
using JuMP
using CSV
using DataFrames
using Plots

# Create a JuMP model, using Ipopt as the solver.
model = Model(Ipopt.Optimizer)

# Set the environment:
#@NLparameter(model, T   == 20.0 + 273.0)   # K,  temperature
#@NLparameter(model, DIN == 20.0)           # uM, external dissolved inorganic nitrogen
#@NLparameter(model, DIC == 100.0)          # uM, external dissolved inorganic carbon
@NLparameter(model, kref_trfFe == 0.0)      # atoms of Fe/min, max turnover rate of not siderophore-bound Fe transporters 
@NLparameter(model, ffe == 200.0)            # pM, external other Fe
#@NLparameter(model, NH4 == 0.0)            # uM, external NH4
#@NLparameter(model, PO4 == 0.0)            # uM, external PO4 (0.06-0.54 uM SO)
#@NLparameter(model, DOP == 0.5)           # uM, external DOP. 0.06 - 0.54 μM in ocean surface waters (Karl and Björkman, 2015)
#@NLparameter(model, I   == 120.0)          # pMol photon m-2 s-1, irradiance
# Out:
# ffe == 200.0

# %%
#Start by running the code with these params
# gs_pdin = 116.0785412727685
# gs_ptrn = 3218.7376646875014
# gs_ptrnh4 = 0.007671221087667696
# gs_ptrdop = 0.0013344932609826523
# gs_ptrpo4 = 102664.27054397759
# gs_psFe = 14.40309395507309
# gs_ptrsFe = 8.224563523602484
# gs_pfFe = 0.0014373508375306872
# gs_ptrfFe = 0.006415037027661122
# gs_pnh4 = 0.0007597452097541392
# gs_pdop = 0.005143783999045397
# gs_pri = 774.8807669127559
# gs_pp = 16627.5427603711    
# gs_pdp = 1368.26989319557                
# gs_pru = 45840.76617426079
# gs_pgl = 34123.15268714034
# gs_pre = 2900.6137794804777                   
# gs_pnt = 7.179601095587591e-5
# gs_pexp = 8.846339141855479e-5
# gs_porg = 0.00036963515341079887
# gs_cin = 1.7398861154855052e6
# gs_cic = 8.484767781452294e6
# gs_cife = 1.5686483193289982e6
# gs_cip = 2.178195154654568e7
# gs_ciorg = 22.112292358308732
# gs_ctag = 2.0000199263891585e7

# %%
# Define the unknown variables that we will optimize for.
@variables(model, begin
        #Growth rate
        logμ   , (start = 0.00047)       # 1/minute, log growth rate
        #Protein pools
        pdin ≥ 0, (start = gs_pdin)      # protein: number of DIN proteins without transporters / um3
        ptrn ≥ 0, (start = gs_ptrn)      # protein: number of transporters / um3
        #plb ≥ 0, (start = 1)            # protein: number of transporters / um3
        ptrnh4 ≥ 0, (start = gs_ptrnh4)  # protein: number of NH4 transporters / um3
        ptrdop ≥ 0, (start = gs_ptrdop)  # protein: number of DOP transporters / um3
        ptrpo4 ≥ 0, (start = gs_ptrpo4)  # protein: number of PO4 transporters / um3
        psFe ≥ 0, (start = gs_psFe)      # protein: number of siderophore-bound Fe utilization proteins / um3
        ptrsFe ≥ 0, (start = gs_ptrsFe)  # protein: number of siderophore-bound Fe transporters / um3
        pfFe ≥ 0, (start = gs_pfFe)      # protein: number of other Fe utilization proteins / um3 
        ptrfFe ≥ 0, (start = gs_ptrfFe)  # protein: number of other Fe transporters / um
        pnh4 ≥ 0, (start = gs_pnh4)      # protein: number of NH4 processing proteins / um3 
        pdop ≥ 0, (start = gs_pdop)      # protein: number of DOP processing proteins / um3 
        pri ≥ 0, (start = gs_pri)         # protein: number of ribosomes / um3 
        pp  ≥ 0, (start = gs_pp)         # protein: number of photosystems / um3 
        pdp ≥ 0, (start = gs_pdp)        # protein: number of damaged photosystems / um3
        pru ≥ 0, (start = gs_pru)          # protein: number of rubisco / um3 
        pgl ≥ 0, (start = gs_pgl)          # protein: number of glycolysis pathway proteins / um3  
        pre ≥ 0, (start = gs_pre)        # protein: number of repair proteins / um3
        pnt ≥ 0, (start = gs_pnt)        # protein: number of nitrogenase units/ um3 
        pexp ≥ 0, (start = gs_pexp)         # protein: number of exporters/ um3 
        porg ≥ 0, (start = gs_porg)      # protein: number of proteins that synthesize organic molecules to export/ um3 
        # # Pools of other macromolecules
        cin ≥ 0, (start = gs_cin)        # other macromolecule: number of internal nitrogen atoms / um3 
        cic ≥ 0, (start = gs_cic)        # other macromolecule: number of internal carbon atoms / um3 
        cife ≥ 0, (start = gs_cife)      # other macromolecule: number of internal iron atoms / um3 
        cip ≥ 0, (start = gs_cip)        # other macromolecule: number of internal phosphorus atoms / um3 
        ciorg ≥ 0, (start = gs_ciorg)    # other macromolecule: number of internal organic C and N molecules / um3 
        ctag≥ 0, (start = gs_ctag)       # other macromolecule: number of lipid droplets / um3 
        #Proteome allocations
        ϕtrn ≥ 0, (start = 0.002)        # relative proteome investment in: transporters (unitless)
        ϕsFe ≥ 0, (start = 0.002)        # relative proteome investment in: siderophore-bound iron utilization proteins (unitless)
        ϕtrsFe ≥ 0, (start = 0.002)      # relative proteome investment in: siderophore-bound iron transporters (unitless)
        ϕfFe ≥ 0, (start = 0.002)        # relative proteome investment in: other iron utilization proteins (unitless)
        ϕtrfFe ≥ 0, (start = 0.002)      # relative proteome investment in: other iron transporters (unitless)
        ϕdin ≥ 0, (start = 0.002)        # relative proteome investment in: DIN proteins without transporters (unitless)
        ϕnh4 ≥ 0, (start = 0.002)        # relative proteome investment in: NH4 processing proteins (unitless)
        ϕtrnh4 ≥ 0, (start = 0.002)      # relative proteome investment in: NH4 transporters (unitless)
        ϕtrpo4 ≥ 0, (start = 0.002)      # relative proteome investment in: PO4 transporters (unitless)
        ϕdop ≥ 0, (start = 0.002)        # relative proteome investment in: DOP processing proteins (unitless)
        ϕtrdop ≥ 0, (start = 0.002)      # relative proteome investment in: DOP transporters (unitless)
        ϕorg ≥ 0, (start = 0.002)        # relative proteome investment in: proteins that synthesize organic compounds to export (unitless)
        ϕri ≥ 0, (start = 0.04)          # relative proteome investment in: ribosomes (unitless)
        ϕp  ≥ 0, (start = 0.03)          # relative proteome investment in: photosystems (unitless)
        ϕru ≥ 0, (start = 0.07)         # relative proteome investment in: rubisco (unitless)
        ϕgl ≥ 0, (start = 0.15)          # relative proteome investment in: glycolysis (unitless)
        ϕre ≥ 0, (start = 0.01)          # relative proteome investment in: repair (unitless)
        ϕnt  ≥ 0, (start = 0.02)         # relative proteome investment in: nitrogenase (unitless)
        ϕexp ≥ 0, (start = 0.002)        # relative proteome investment in: exporters (unitless)
        #ϕlb ≥ 0, (start = 0.002)        # relative proteome investment in: lipid biosynthesis (unitless)
        #αlm ≥ 0, (start = 0.2)          # fraction of lipid synthesis flux used to: synthesize membrane lipids (unitless)
        #αtag≥ 0, (start = 0.6)          # fraction of lipid synthesis flux used to: synthesize lipid storage (unitless)

end)
# Out:
# (logμ, pdin, ptrn, ptrnh4, ptrdop, ptrpo4, psFe, ptrsFe, pfFe, ptrfFe, pnh4, pdop, pri, pp, pdp, pru, pgl, pre, pnt, pexp, porg, cin, cic, cife, cip, ciorg, ctag, ϕtrn, ϕsFe, ϕtrsFe, ϕfFe, ϕtrfFe, ϕdin, ϕnh4, ϕtrnh4, ϕtrpo4, ϕdop, ϕtrdop, ϕorg, ϕri, ϕp, ϕru, ϕgl, ϕre, ϕnt, ϕexp)

# %%
gs_ctag, gs_pgl, gs_pru, gs_pp, gs_pri, gs_pnt
# Out:
# (2.0000199263891585e7, 34123.15268714034, 45840.76617426079, 16627.5427603711, 774.8807669127559, 7.179601095587591e-5)

# %%
gs_cip, gs_pexp, gs_cic, gs_cife, gs_cin, gs_porg, gs_pexp
# Out:
# (2.178195154654568e7, 8.846339141855479e-5, 8.484767781452294e6, 1.5686483193289982e6, 1.7398861154855052e6, 0.00036963515341079887, 8.846339141855479e-5)

# %%
#C/N ratio should be 6.57
#C/Fe ratio should be 1/158e-6=6329.11
#C/P ratio should be 348.2
gs_cic/gs_cin
#total C should be 1.02-4.3e11`
#total N should be 1.7-7.2e10
#total Fe should be 2.62-6.79e7
#total P should be N/53
# Out:
# 4.876622501861088

# %%
#N/P ratio should be 53
gs_cin/gs_cip
# Out:
# 0.0798774210734771

# %%
#C/Fe ratio should be 1/158e-6=6329.11
gs_cic/gs_cife
# Out:
# 5.408967502085949

# %%
#Fe/P ratio should be 0.55
1.14e11/1.8e7
# Out:
# 6333.333333333333

# %%
# Set the objective: maximize the log growth rate (logμ).
@objective(model, Max, logμ)
# Out:
# logμ

# %% [markdown]
# ## General equation for reaction rates
#
# The reaction rates catalyzed by a given protein i are represented by a Michaelis-Menten type equation:
#
# $$
#
# v_i = k_i p_i \frac{S_i}{S_1 + K_i}
# $$
#
# $k_i$ = turnover rate \
# $p_i$ = concentration of protein \
# $S_i$ = substrate concentration \
# $K_i$ = half-saturation constant
#
#
# It is assumed that all enzymatic rates in the cell increase with temperature following the Arrhenius equation:
#
# $$
#
# k_i = k_{ref_i} \gamma _{T},
#
# $$
#
# where
#
# $$
#  \gamma _{T}=exp \left[\frac{E_a}{R} \left(\frac{1}{T_{ref}}-\frac{1}{T}\right)\right]
#  $$
#
#  in which $k_{ref_i}$ is the maximum turnover rate at a reference temperature $T_{ref}$ (in kelvin), $E_a$ is the activation energy (eV), R is Boltzmann’s constant (eV $K^{−1}$), and T is the actual temperature (K).
#
#  ## Protein synthesis flux
#
# $$
#
# v_{ri} = k_{ri} p_{ri} \frac{c_{ic}}{c_{ic} + K_{ic}} \frac{c_{in}}{c_{in} + K_{in}}
#
# $$
#
# $c_{ic}$ = pool of internal carbon \
# $c_{in}$ = pool of internal nitrogen
#
#  ## Carbon metabolism
#
# $$
# v_{ru} = k_{ru} p_{ru} \frac{DIC}{DIC + K_{ru}}
# $$
#
# The internal pool of C is given by:
#
# $$
# \frac{dc_{ic}}{dt}=v_{ru}-v_{ri}\eta_{aac} - v_{gl} -\mu c_{ic} = 0
# $$
#
# ## Nitrogen metabolism
#
# In this model, *Trichodesmium* cells can either utilize NH4, fixed N2 or DIN as N sources.
#
# The rate of $NH_4$ utilization is given by:
#
# $$
# v_{nh4} = k_{nh4} p_{nh4} \frac{NH_4}{NH_4 + K_{nh4}}
# $$
#
# The rate of DIN transport is given by:
#
# $$
# v_{trn} = k_{trn} p_{trn} \frac{DIN}{DIN + K_{trn}}
# $$
#
# The rate of $N_2$ fixation is given by:
#
# $$
# v_{nt} = k_{nt} p_{nt} \frac{N_2}{N_2 + K_{nt}}
# $$
#
# We assume that $N_2$ is not limited, so that $N_2 >> K_{nt}$. Then,
#
# $$
# v_{nt} \approx k_{nt} p_{nt}
# $$
#
# We also assume that $v_{trn}$ and $v_{DIN}$, the rate of nitrate and nitrite reduction, are equal (because reductases are much more efficient than transporters), such that:
#
# $$
# v_{trn} = v_{DIN} = k_{DIN} p_{DIN}
# $$
#
# Constraint:
#
# $$
# p_{DIN} \geq \frac{v_{trn}}{k_{DIN}}
# $$
#
# The internal pool of N is given by:
#
# $$
# \frac{dC_{in}}{dt}=v_{trn}+v_{nt}+v_{nh4}-v_{ri}\eta_{aan} -\mu c_{in} = 0
# $$
#
# ## Iron metabolism
#
# *Trichodesmium* can either take siderophore-bound Fe (sFe) or other forms of iron, including organic-bound Fe, particulate-bound Fe, or free Fe (fFe).
#
# The uptake rate of siderophore-bound Fe is given by:
#
# $$
# v_{sFe}=k_{{sFe}}p_{{sFe}}\frac{sFe}{sFe+K_{{sFe}}}
# $$
#
# The uptake rate of other forms of iron is given by:
#
# $$
# v_{{trfFe}}=k_{{trfFe}}p_{{trfFe}}\frac{fFe}{fFe+K_{{trfFe}}}
# $$
#
# The internal pool of Fe is given by:
#
# $$
# \frac{dFe_{in}}{dt}=v_{{sFe}}+v_{{trfFe}}-v_{ri} \phi_p \eta_{paafe}-v_{ri} \phi_{nt} \eta_{ntaafe}-\mu C_{iFe} = 0,
# $$
#
# where $ v_{ri} \phi_p \eta_{paafe}$ is the Fe required to make photosystems, and $v_{ri} \phi_{nt} \eta_{ntaafe}$ is the Fe required to make nitrogenase.
#
# We also assume that $v_{trfFe}$ and $v_{fFe}$, the rate of other Fe processing proteins, are equal (because the processing proteins are much more efficient than transporters), such that:
#
# $$
# v_{trfFe} = v_{fFe} = k_{fFe} p_{fFe}
# $$
#
# Constraint:
#
# $$
# p_{fFe} \geq \frac{v_{trfFe}}{k_{fFe}}
# $$
#
# ## Photosystems
#
# The rate of photosystems is now dependent on the internal concentrations of Fe also:
#
# $$
# v_{{p}}=k_{{p}}p_{{p}}\frac{I}{I+K_{{p, I}}} \frac{c_{iFe}}{c_{iFe}+K_{p, Fe}}
# $$
#
# ## Phosphorus metabolism
#
# We will assume that *Trichodesmium* can either take dissolved organic phosphorus (DOP)/phosphite or phosphate/Pi. AHLs from the epibionts may enhance the uptake of DOP, as well as phosphonates.
#
# The uptake rate of DOP is given by:
#
# $$
# v_{trDOP}=k_{{trdop}}p_{{trdop}}\frac{DOP}{DOP+K_{{trdop}}}
# $$
#
# The uptake rate of phosphate is given by:
#
# $$
# v_{{trPO_4}}=k_{{trpo4}}p_{{trpo4}}\frac{PO_4}{PO_4+K_{{trpo4}}}
# $$
#
# The internal pool of P is given by:
#
# $$
# \frac{dC_{ip}}{dt}=v_{{trDOP}}+v_{{PO_4}}-v_{lb} \cdot αlm \cdot flmp \cdot ηlip - \frac{ecost}{3} \cdot 0.001 -\mu C_{ip} = 0,
# $$
#
# where $ {v_{lb} \cdot αlm \cdot flmp \cdot ηlip} $ is the P required to make membrane phospholipids, and $\frac{ecost}{3} \cdot 0.001$ is the P required to make ATP (very small since most ATP is recycled inside the cell).
#
# We also assume that $v_{trDOP}$ and $v_{DOP}$, the rate of DOP processing proteins, are equal (because the processing proteins are much more efficient than transporters), such that:
#
# $$
# v_{trDOP} = v_{DOP} = k_{DOP} p_{DOP}
# $$
#
# Constraint:
#
# $$
# p_{DOP} \geq \frac{v_{trDOP}}{k_{DOP}}
# $$
#
# #### Export of molecules
#
# The internal pool of organic molecules to export is synthesized from the internal C and N pools, such that:
#
# $$
# v_{org}=k_{org}p_{org}\frac{c_{ic}}{c_{ic}+K_{org, C}} \frac{c_{in}}{c_{in}+K_{org, N}}
# $$
#
# The rate of export of the internal pool of organic molecules of C and N is:
#
# $$
# v_{exp}=k_{exp}p_{exp}\frac{c_{iorg}}{c_{iorg}+K_{exp}}
# $$
#
# The internal pool of organic molecules to export is given by:
#
# $$
# \frac{dC_{iorg}}{dt}=v_{{org}}-v_{{exp}}-\mu C_{iorg} = 0
# $$

# %%
# Define any intermediate calculations.
@NLexpressions(model, begin
        DIC, 100.0
        DIN, 2.0
        T, 20.0 + 273.0
        I, 120.0
        NH4, 0.0
        DOP, 0.0
        PO4, 0.5
        sfe, 1.0
      #rate constants
        γTa,   exp(Ea*(1.0/(R*Tref) - 1.0/(R*T)))                                              # rate constant for enzymes; unitless
        γTd,   exp(Ed*(1.0/(R*Td) - 1.0/(R*T)))                                                # rate constant for temperature-dependent damage; unitless
        γTad,  exp(Etr*(1.0/(R*Tref) - 1.0/(R*T)))                                             # rate constant for nitrogen transport; unitless
        γTm,   (Tmax - T)/(Tmax - Tmin)                                                        # unitless
        #reaction rates 
        vp,  ( kref["p"] ) * pp * I / (K["p"] + I)                                             # photosystems reaction rate; molecules of photons/μm3/min
        vru, ( kref["ru"] * γTa ) * pru * DIC / ( K["ru"] + DIC )                              # rubisco reaction rate; atoms of carbon/pM3/min
        vtrn, ( kref["trn"] * γTad ) * ptrn * DIN/ ( K["trn"] + DIN)                           # DIN reaction rate (limited by the nitrogen transporters reaction rate); atoms of nitrogen/μm3/min
        vri, ( kref["ri"] * γTa ) * pri * (cic / ( K["ic"] + cic )) * (cin / ( K["in"] + cin)) # protein synthesis rate; molecules of amino acids/μm3/min
        #vlb, ( kref["lb"] * γTa ) * plb * cic / ( K["lb"] + cic )                             # lipid synthesis rate; atoms of carbon/pM3/min
        #vld, ( kref["ld"] * γTa ) * pld                                                       # lipid degradation rate; atoms of carbon/pM3/min
        vd,  ( kref["d"]  * γTd ) * pp * (ctag_max/ctag)                                       # heat damage rate; molecules of photosystems/pM3/min
        vre,  ( kref["re"]  * γTa ) * pre * (pdp/(pdp + pp))                                   # repair rate; molecules of photosystems/μm3/min
        #vre, ( kref["re"] * γTa ) * pre * (pdp/(pdp + K["f"]))                                # repair rate; molecules of photosystems/μm3/min; alternative approach
        #kref_exp, DOP^2.2
        kref_exp, 120
        vexp, ( kref_exp * γTa) * pexp * (ciorg / (K["exp"] + ciorg))                       # Organic molecules export rate; C and N org molecules/μm3/min
        vorg, ( kref["org"] * γTa) * porg * (cic / ( K["corg"] + cic )) * (cin / ( K["norg"] + cin)) # Organic molecules export rate; C and N org molecules/μm3/min
        #sfe= 0.0 .+ [0.0:45:2000.0;]
        sfet, sfe + sfe * vexp
        vgl,   ( kref["gl"] * γTa ) * pgl                                                      # glycolysis rate; atoms of carbon/μm3/min
        vnt,   ( kref["nt"] * γTa ) * pnt * (cife / ( K["ntfe"] + cife))                        # N2 fixation rate; atoms of nitrogen/μm3/min                                              
        vsFe, ( kref["sFe"] * γTa) * psFe * (sfet / (K["sFe"] + sfet))                            # siderophore-bound Fe reduction rate; atoms of Fe/μm3/min 
        vtrfFe, ( kref_trfFe * γTa) * ptrfFe * (ffe / (K["trfFe"] + ffe))                           # free Fe reduction rate; atoms of Fe/μm3/min
        vnh4, ( kref["nh4"] * γTa) * pnh4 * (NH4 / (K["nh4"] + NH4))                           # NH4 processing rate; molecules of NH4/μm3/min
        vtrdop, ( kref["trdop"] * γTa) * pdop * (DOP / (K["trdop"] + DOP))                           # DOP processing rate; molecules of DOP/μm3/min
        vtrpo4, ( kref["trpo4"] * γTa) * ptrpo4 * (PO4 / (K["trpo4"] + PO4))                           # PO4 processing rate; molecules of PO4/μm3/min
        cgu,  vgl / ηguc * td                                                                  # storage pool for glucose to fuel dark respiration; molecules of glucose/μm3
        clm, (β - (ptrn+ ptrnh4 + ptrdop + pexp + ptrsFe + ptrfFe) * s_trn)/s_lm                                                             # lipid membrane concentration calculated from a set β as a function of N transporters; lipid molecules/μm3 
        #cli,  vld / ηlic * td                                                                 # storage pool for lipids to fuel dark respiration; molecules of lipid storage/μm3 
        #ηaan,  ηaac * ((ϕtrn + ϕru + ϕlb + ϕld + ϕgl + ϕre + ϕnt)*Qpt + ϕri*Qri + ϕp*Qp)      # atoms of nitrogen / molecule of amino acid
        ηaan,  ηaac * ((ϕtrn + ϕru + ϕgl + ϕre + ϕnt + ϕdin + ϕnh4 + ϕsFe + ϕfFe + ϕdop 
        + ϕexp + ϕorg + ϕtrnh4 + ϕtrdop + ϕtrpo4 + ϕtrsFe + ϕtrfFe)*Qpt + ϕri*Qri + ϕp*Qp)                                                     # atoms of nitrogen / molecule of amino acid
    
        vol,     4/3*π*(β*3)^3                                                                 # cell biovolume; um3
        ϵ,       1.0 - (pp + pdp) * Vp - ctag * Vli                                            # fraction of the biovolume not occupied by photosystems nor lipid storage; unitless  
        tot_p,   (pp + pdp)*ηp + pru*ηru + ptrn*ηtrn + pdin*ηdin+ + pri*ηri + pgl*ηgl +
        pre*ηre + pnh4*ηnh4 + ptrnh4*ηtrnh4 + ptrdop*ηtrdop + ptrpo4*ηtrpo4 + psFe*ηsFe + 
        pfFe*ηfFe + ptrsFe*ηtrsFe + ptrfFe*ηtrfFe + pdop*ηdop + pnt*ηnt + pexp*ηexp + 
        porg*ηorg + cot*ηot                                                                     # total protein content; Da/μm3
        ecost, vtrn*(e_trn+e_din) + vri*e_ri + vd*e_u + vre*e_re + vnt*e_nt + 
        vsFe*(e_sfe+e_trsfe) + vtrfFe*(e_ffe+e_trffe) + vnh4*(e_nh4+e_trnh4) + 
        vtrdop * (e_dop+e_trdop) + vtrpo4*e_trpo4 + vexp*e_exp + vgl*ec_gl                      # energetic demands of photosystems other than rubisco; molecules of ATP/μm3/min
        D, ηru*pru + ηri*pri + ηnt*pnt + pdin*ηdin + ηtrn*ptrn + pnh4*ηnh4 + 
        ptrnh4*ηtrnh4 + ptrdop*ηtrdop + ptrpo4*ηtrpo4 + ptrsFe*ηtrsFe + ptrfFe*ηtrfFe + 
        psFe*ηsFe + pfFe*ηfFe + ηgl*pgl + ηre*pre + pdop*ηdop + pexp*ηexp + porg*ηorg + 
        ηin*cin + ηic*cic + ηife*cife + ηip*cip + cgu*ηgu + cot*ηot     

        atp, ecost*exp(logμ)
        Qn,   (ptrn*ηtrn*Qpt + pdin*ηdin*Qpt + pru*ηru*Qpt + pgl*ηgl*Qpt + pre*ηre*Qpt + 
        pri*ηri*Qri + pnt*ηnt*Qpt +psFe*ηsFe*Qpt + pfFe*ηfFe*Qpt + pnh4*ηnh4*Qpt +
        ptrnh4*ηtrnh4*Qpt + ptrdop*ηtrdop*Qpt + ptrpo4*ηtrpo4*Qpt + ptrsFe*ηtrsFe*Qpt +
        ptrfFe*ηtrfFe*Qpt + pdop*ηdop*Qpt + pexp*ηexp*Qpt + porg*ηorg*Qpt +
        (pp + pdp)*ηp*Qp + cot*ηot*Qpt)* ηaac/ηaa + cin                                                       # total number of atoms of nitrogen/um3
        Qc,   (ptrn*ηtrn + pdin*ηdin + pru*ηru + pgl*ηgl + pre*ηre + (pp + pdp)*ηp + 
        pri*ηri + pnt*ηnt + psFe*ηsFe + pfFe*ηfFe + pnh4*ηnh4 + pexp*ηexp +
        porg*ηorg + pdop*ηdop + ptrnh4*ηtrnh4 + ptrdop*ηtrdop + ptrpo4*ηtrpo4 + 
        ptrsFe*ηtrsFe + ptrfFe*ηtrfFe + cot*ηot)*ηaac/ηaa + cic + ctag*ηlic + cgu*ηguc                                                                    # total number of atoms of carbon/um3
        Qf,   (ptrn*ηtrn*Fpt + pru*ηru*Fpt + pgl*ηgl*Fpt + pre*ηre*Fpt + pri*ηri*Fpt + 
        pnt*ηnt*Fnt +ptrn*ηtrn*Fpt +psFe*ηsFe*Fpt + pfFe*ηfFe*Fpt +  pdop*ηdop*Fpt+ 
        pexp*ηexp*Fpt + porg*ηorg*Fpt + ptrnh4*ηtrnh4*Fpt + ptrdop*ηtrdop*Fpt + 
        ptrpo4*ηtrpo4*Fpt + ptrsFe*ηtrsFe*Fpt + ptrfFe*ηtrfFe*Qpt + (pp + pdp)*ηp*Fp + 
        cot*ηot*Fpt)* ηaac/ηaa + cife                                                                       # total number of atoms of iron/um3
        Qp, (clm*flmp*ηlic*ηlip) + pru*ηrup + pgl*ηglp + atp*3 + cip                                               # total number of atoms of phosphorus/um3

        Fcell, Qc/Qf                                                                           # carbon to iron quota of the cell
        Qcell, Qc/Qn                                                                           # carbon to nitrogen quota of the cell
        Pcell, Qc/Qp                                                                           # carbon to phosphorus quota of the cell
        
                                                      # concentration of all macromolecules except for photosystems, lipid storage and membrane components; Da/μm3 
end)
# Out:
# (subexpression[1]: 100.0, subexpression[2]: 2.0, subexpression[3]: 20.0 + 273.0, subexpression[4]: 120.0, subexpression[5]: 0.0, subexpression[6]: 0.0, subexpression[7]: 0.5, subexpression[8]: 1.0, subexpression[9]: exp(0.5 * (1.0 / (8.62e-5 * 293.0) - 1.0 / (8.62e-5 * subexpression[3]))), subexpression[10]: exp(1.5 * (1.0 / (8.62e-5 * 316.0) - 1.0 / (8.62e-5 * subexpression[3]))), subexpression[11]: exp(0.25 * (1.0 / (8.62e-5 * 293.0) - 1.0 / (8.62e-5 * subexpression[3]))), subexpression[12]: (318.0 - subexpression[3]) / (318.0 - 276.0), subexpression[13]: (7800.0 * pp * subexpression[4]) / (1.0 + subexpression[4]), subexpression[14]: ((170.6 * subexpression[9]) * pru * subexpression[1]) / (1.0 + subexpression[1]), subexpression[15]: ((120.0 * subexpression[11]) * ptrn * subexpression[2]) / (5.0 + subexpression[2]), subexpression[16]: (957.0 * subexpression[9]) * pri * (cic / (100000.0 + cic)) * (cin / (10000.0 + cin)), subexpression[17]: (1000.0 * subexpression[10]) * pp * (2.0e7 / ctag), subexpression[18]: (1000.0 * subexpression[9]) * pre * (pdp / (pdp + pp)), subexpression[19]: 120.0, subexpression[20]: (subexpression[19] * subexpression[9]) * pexp * (ciorg / (1.0 + ciorg)), subexpression[21]: (60.0 * subexpression[9]) * porg * (cic / (10000.0 + cic)) * (cin / (10000.0 + cin)), subexpression[22]: subexpression[8] + subexpression[8] * subexpression[20], subexpression[23]: (120.0 * subexpression[9]) * pgl, subexpression[24]: (1061.0 * subexpression[9]) * pnt * (cife / (1000.0 + cife)), subexpression[25]: (69.2 * subexpression[9]) * psFe * (subexpression[22] / (1.0 + subexpression[22])), subexpression[26]: (kref_trfFe * subexpression[9]) * ptrfFe * (ffe / (1.0 + ffe)), subexpression[27]: (88.8 * subexpression[9]) * pnh4 * (subexpression[5] / (1.0 + subexpression[5])), subexpression[28]: (120.0 * subexpression[9]) * pdop * (subexpression[6] / (1.0 + subexpression[6])), subexpression[29]: (120.0 * subexpression[9]) * ptrpo4 * (subexpression[7] / (1.0 + subexpression[7])), subexpression[30]: (subexpression[23] / 6.0) * 720.0, subexpression[31]: (6.0 - (ptrn + ptrnh4 + ptrdop + pexp + ptrsFe + ptrfFe) * 1.26e-5) / 5.0e-7, subexpression[32]: 5.0 * ((ϕtrn + ϕru + ϕgl + ϕre + ϕnt + ϕdin + ϕnh4 + ϕsFe + ϕfFe + ϕdop + ϕexp + ϕorg + ϕtrnh4 + ϕtrdop + ϕtrpo4 + ϕtrsFe + ϕtrfFe) * 0.2 + ϕri * 0.33 + ϕp * 0.1), subexpression[33]: (4.0 / 3.0) * 3.141592653589793 * (6.0 * 3.0) ^ 3.0, subexpression[34]: (1.0 - (pp + pdp) * 3.0e-5) - ctag * 1.5e-9, subexpression[35]: (pp + pdp) * 1.40129e6 + pru * 342100.0 + ptrn * 82940.0 + pdin * 218790.0 + +pri * 2.12553e6 + pgl * 452320.0 + pre * 698500.0 + pnh4 * 276650.0 + ptrnh4 * 53680.0 + ptrdop * 157520.0 + ptrpo4 * 139920.0 + psFe * 313390.0 + pfFe * 341770.0 + ptrsFe * 183150.0 + ptrfFe * 146630.0 + pdop * 80080.0 + pnt * 772640.0 + pexp * 226270.0 + porg * 5170.0 + 782.7082672065418 * 1.6009301e8, subexpression[36]: subexpression[15] * (1.0 + 5.2) + subexpression[16] * 48.0 + subexpression[17] * 4.5 + subexpression[18] * 4.5 + subexpression[24] * 8.0 + subexpression[25] * (8.8 + 0.0) + subexpression[26] * (4.6 + 1.0) + subexpression[27] * (3.6 + 0.0) + subexpression[28] * (0.0 + 2.0) + subexpression[29] * 1.0 + subexpression[20] * 1.0 + subexpression[23] * 2.0, subexpression[37]: 342100.0 * pru + 2.12553e6 * pri + 772640.0 * pnt + pdin * 218790.0 + 82940.0 * ptrn + pnh4 * 276650.0 + ptrnh4 * 53680.0 + ptrdop * 157520.0 + ptrpo4 * 139920.0 + ptrsFe * 183150.0 + ptrfFe * 146630.0 + psFe * 313390.0 + pfFe * 341770.0 + 452320.0 * pgl + 698500.0 * pre + pdop * 80080.0 + pexp * 226270.0 + porg * 5170.0 + 14.0 * cin + 12.0 * cic + 56.0 * cife + 31.0 * cip + subexpression[30] * 180.0 + 782.7082672065418 * 1.6009301e8, subexpression[38]: subexpression[36] * exp(logμ), subexpression[39]: ((ptrn * 82940.0 * 0.2 + pdin * 218790.0 * 0.2 + pru * 342100.0 * 0.2 + pgl * 452320.0 * 0.2 + pre * 698500.0 * 0.2 + pri * 2.12553e6 * 0.33 + pnt * 772640.0 * 0.2 + psFe * 313390.0 * 0.2 + pfFe * 341770.0 * 0.2 + pnh4 * 2 ...

# %%
# Define the system of equations and constraints.
@constraints(model, begin
        ϕp + ϕru + ϕtrn + ϕdin + ϕri + ϕgl + ϕre + ϕnt + ϕsFe + ϕfFe + ϕnh4 + ϕdop + 
        ϕexp + ϕorg + ϕtrnh4 + ϕtrdop + ϕtrpo4 + ϕtrsFe + ϕtrfFe ==  0.5 #the sum of all proteome relative investments is assumed to equal 1 - ϕother
        #αlm + αtag == 1.0 #the lipids pool is comprised of the flux used to synthesize membrane lipids (αlm), those used for dark respiration (αld), and the ones that can mitigate damage (αtag) 
        #ϕld == 0
end)
# Out:
# (ϕtrn + ϕsFe + ϕtrsFe + ϕfFe + ϕtrfFe + ϕdin + ϕnh4 + ϕtrnh4 + ϕtrpo4 + ϕdop + ϕtrdop + ϕorg + ϕri + ϕp + ϕru + ϕgl + ϕre + ϕnt + ϕexp = 0.5,)

# %%
@NLconstraints(model, begin
        (ptrn + ptrnh4 + ptrdop + pexp + ptrsFe + ptrfFe) / 
        clm ≤ Mmin + (Mmax * γTm)                                                 # constraint on the transporter to lipid ratio in the membrane
        vtrn /kref["din"] ≤ pdin                                                  # constraint on the ratio of N transporter to DIN proteins
        vnh4 /kref["trnh4"] ≤ ptrnh4                                              # constraint on the ratio of NH4 transporter to processing proteins
        vtrdop /kref["dop"] ≤ pdop                                                # constraint on the ratio of DOP transporter to processing proteins
        vsFe /kref["trsFe"] ≤ ptrsFe                                              # constraint on the ratio of siderophore-bound Fe transporter to processing proteins
        vtrfFe /kref["fFe"] ≤ pfFe                                                # constraint on the ratio of other Fe transporter to processing proteins
        #β * (s_trn * ptrn + s_lm * clm) == 1.0                                   # constraint on the volume to surface area ratio of the cell
        pdp / (pdp + pp) == ( ( kref["d"]  * γTd ) * pp * 
        (ctag_max/ctag) ) / ( kref["re"] * γTa * pre )                            # damage (vd) and repair (vre) dynamics assuming vd = vre
        Fcell ≤ 7000                                                              # constraints based on the intracellular ratios of Trichodesmium
        Pcell ≤ 500                                                               # constraints based on the intracellular ratios of Trichodesmium
        ϕp * vri * 1/(ηp/ηaa) - exp(logμ) * (pp + pdp) == 0.0                    # protein: molecules of photosystems/μm3
        # alternative approach to model folding/unfolding of photosystems:
        #ϕp * vri * 1/(ηp/ηaa) + vre - vd - exp(logμ) * pp == 0.0                  # protein: functional photosystems/μm3
        #vd - vre - exp(logμ) * pdp == 0.0                                         # protein: damaged photosystems/μm3
        ϕru * vri * 1/(ηru/ηaa) - exp(logμ) * pru == 0.0                         # protein: rubisco/μm3
        ϕtrn  * vri * 1/(ηtrn/ηaa)  - exp(logμ) * ptrn  == 0.0                    # protein: N transporters/μm3
        ϕdin  * vri * 1/(ηdin/ηaa)  - exp(logμ) * pdin  == 0.0                    # protein: DIN proteins/μm3
        ϕri * vri * 1/(ηri/ηaa) - exp(logμ) * pri == 0.0                         # protein: ribosomes/μm3
        ϕnt * vri * 1/(ηnt/ηaa) - exp(logμ) * pnt == 0.0                         # protein: nitrogenase/μm3
        #ϕlb * vri * 1/(ηlb/ηaa) - exp(logμ) * plb == 0.0                         # protein: lipid synthesis proteins/μm3
        #ϕld * vri * 1/(ηld/ηaa) - exp(logμ) * pld == 0.0                         # protein: lipid degradation proteins/μm3
        ϕgl * vri * 1/(ηgl/ηaa) - exp(logμ) * pgl == 0.0                         # protein: glycolysis proteins/μm3
        ϕre * vri * 1/(ηre/ηaa) - exp(logμ) * pre == 0.0                         # protein: repair proteinsμm3
        ϕsFe * vri * 1/(ηsFe/ηaa) - exp(logμ) * psFe == 0.0                       # protein: siderophore-bound Fe processing proteins/μm3
        ϕtrsFe * vri * 1/(ηtrsFe/ηaa) - exp(logμ) * ptrsFe == 0.0                 # protein: siderophore-bound Fe transporters/μm3
        ϕfFe * vri * 1/(ηfFe/ηaa) - exp(logμ) * pfFe == 0.0                       # protein: other Fe processing proteins/μm3
        ϕtrfFe * vri * 1/(ηtrfFe/ηaa) - exp(logμ) * ptrfFe == 0.0                 # protein: other Fe transporters/μm3
        ϕnh4 * vri * 1/(ηnh4/ηaa) - exp(logμ) * pnh4 == 0.0                       # protein: NH4 processing proteins/μm3
        ϕtrpo4 * vri * 1/(ηtrpo4/ηaa) - exp(logμ) * ptrpo4 == 0.0                 # protein: PO4 transporters/μm3
        ϕdop * vri * 1/(ηdop/ηaa) - exp(logμ) * pdop == 0.0                       # protein: DOP processing proteins/μm3
        ϕtrdop * vri * 1/(ηtrdop/ηaa) - exp(logμ) * ptrdop == 0.0                 # protein: DOP transporters/μm3
        ϕexp * vri * 1/(ηexp/ηaa) - exp(logμ) * pexp == 0.0                       # protein: exporters/μm3
        ϕorg * vri * 1/(ηorg/ηaa) - exp(logμ) * porg == 0.0                       # protein: exporters/μm3
        ϕtrnh4 * vri * 1/(ηtrnh4/ηaa) - exp(logμ) * ptrnh4 == 0.0                 # protein: NH4 transporters/μm3
        vtrn + vnt + vnh4 - vri*ηaan -vorg - exp(logμ) * cin == 0.0                # internal pool of nitrogen/μm3
        vru - vri*ηaac - vgl - vorg*3 - exp(logμ) * cic == 0.0                    # internal pool of carbon/μm3
        vsFe + vtrfFe - vri*ϕp*ηpaafe -vri*ϕnt*ηntaafe - exp(logμ) * cife == 0.0     # internal pool of iron/μm3
        vtrpo4 + vtrdop  - vgl*ec_gl*ηatpp/ηguc - vri*ϕru*ηrup*ηaa/(ηaac*ηru) - 
        exp(logμ)*clm*flmp*ηlip - exp(logμ) * cip == 0.0   # internal pool of phosphorus/μm3
        vorg - vexp -  exp(logμ) * ciorg == 0.0                                            # internal pool of organic N and C molecules to export/μm3
        #αlm * vlb/ηlic - exp(logμ) * clm == 0.0                                  # membrane lipids/μm3 (evolved)
        #αtag * vlb/ηlic - exp(logμ) * ctag == 0.0                                # lipid storage/μm3 (used to regulate heat-damage; not used in dark respiration)
        ctag ≤ ctag_min + ctag_max                                               # constraint on the maximum concentration of ctag; lipid storage/μm3
        #vld == αld * vlb                                                         # lipid degradation rate; molecules of carbon/μm3/min
        # energetic requirements:
        vp * e_p ≥ vru * e_ru                                                    # rubisco costs are paid by photosystems; molecules of ATP/μm3/min
        ecost ≤ vp*e_p - vru*e_ru                                                # total ATP cost; molecules of ATP/μm3/min
        ecost*fdr ≤ vgl*ep_gl                                                     # dark respiration; molecules of ATP/μm3/min
        1/ϵ * D ≤ Dmax                                                           # density constraint; Da/μm3
        
end)
# Out:
# (((ptrn + ptrnh4 + ptrdop + pexp + ptrsFe + ptrfFe) / subexpression[31] - (3.0e-5 + 0.00045 * subexpression[12])) - 0.0 ≤ 0, (subexpression[15] / 2662.0 - pdin) - 0.0 ≤ 0, (subexpression[27] / 120.0 - ptrnh4) - 0.0 ≤ 0, (subexpression[28] / 954.06 - pdop) - 0.0 ≤ 0, (subexpression[25] / 120.0 - ptrsFe) - 0.0 ≤ 0, (subexpression[26] / 151.3 - pfFe) - 0.0 ≤ 0, (pdp / (pdp + pp) - ((1000.0 * subexpression[10]) * pp * (2.0e7 / ctag)) / (1000.0 * subexpression[9] * pre)) - 0.0 = 0, subexpression[43] - 7000.0 ≤ 0, subexpression[45] - 500.0 ≤ 0, ((ϕp * subexpression[16] * 1.0) / (1.40129e6 / 110.0) - exp(logμ) * (pp + pdp)) - 0.0 = 0, ((ϕru * subexpression[16] * 1.0) / (342100.0 / 110.0) - exp(logμ) * pru) - 0.0 = 0, ((ϕtrn * subexpression[16] * 1.0) / (82940.0 / 110.0) - exp(logμ) * ptrn) - 0.0 = 0, ((ϕdin * subexpression[16] * 1.0) / (218790.0 / 110.0) - exp(logμ) * pdin) - 0.0 = 0, ((ϕri * subexpression[16] * 1.0) / (2.12553e6 / 110.0) - exp(logμ) * pri) - 0.0 = 0, ((ϕnt * subexpression[16] * 1.0) / (772640.0 / 110.0) - exp(logμ) * pnt) - 0.0 = 0, ((ϕgl * subexpression[16] * 1.0) / (452320.0 / 110.0) - exp(logμ) * pgl) - 0.0 = 0, ((ϕre * subexpression[16] * 1.0) / (698500.0 / 110.0) - exp(logμ) * pre) - 0.0 = 0, ((ϕsFe * subexpression[16] * 1.0) / (313390.0 / 110.0) - exp(logμ) * psFe) - 0.0 = 0, ((ϕtrsFe * subexpression[16] * 1.0) / (183150.0 / 110.0) - exp(logμ) * ptrsFe) - 0.0 = 0, ((ϕfFe * subexpression[16] * 1.0) / (341770.0 / 110.0) - exp(logμ) * pfFe) - 0.0 = 0, ((ϕtrfFe * subexpression[16] * 1.0) / (146630.0 / 110.0) - exp(logμ) * ptrfFe) - 0.0 = 0, ((ϕnh4 * subexpression[16] * 1.0) / (276650.0 / 110.0) - exp(logμ) * pnh4) - 0.0 = 0, ((ϕtrpo4 * subexpression[16] * 1.0) / (139920.0 / 110.0) - exp(logμ) * ptrpo4) - 0.0 = 0, ((ϕdop * subexpression[16] * 1.0) / (80080.0 / 110.0) - exp(logμ) * pdop) - 0.0 = 0, ((ϕtrdop * subexpression[16] * 1.0) / (157520.0 / 110.0) - exp(logμ) * ptrdop) - 0.0 = 0, ((ϕexp * subexpression[16] * 1.0) / (226270.0 / 110.0) - exp(logμ) * pexp) - 0.0 = 0, ((ϕorg * subexpression[16] * 1.0) / (5170.0 / 110.0) - exp(logμ) * porg) - 0.0 = 0, ((ϕtrnh4 * subexpression[16] * 1.0) / (53680.0 / 110.0) - exp(logμ) * ptrnh4) - 0.0 = 0, ((((subexpression[15] + subexpression[24] + subexpression[27]) - subexpression[16] * subexpression[32]) - subexpression[21]) - exp(logμ) * cin) - 0.0 = 0, ((((subexpression[14] - subexpression[16] * 5.0) - subexpression[23]) - subexpression[21] * 3.0) - exp(logμ) * cic) - 0.0 = 0, ((((subexpression[25] + subexpression[26]) - subexpression[16] * ϕp * 0.0011774864589057226) - subexpression[16] * ϕnt * 0.0009965831435079728) - exp(logμ) * cife) - 0.0 = 0, (((((subexpression[29] + subexpression[28]) - (subexpression[23] * 2.0 * 3.0) / 6.0) - (subexpression[16] * ϕru * 2.0 * 110.0) / (5.0 * 342100.0)) - exp(logμ) * subexpression[31] * 0.554 * 0.02564102564102564) - exp(logμ) * cip) - 0.0 = 0, ((subexpression[21] - subexpression[20]) - exp(logμ) * ciorg) - 0.0 = 0, (ctag - (200.0 + 2.0e7)) - 0.0 ≤ 0, (subexpression[13] * 1.0 - subexpression[14] * 10.0) - 0.0 ≥ 0, (subexpression[36] - (subexpression[13] * 1.0 - subexpression[14] * 10.0)) - 0.0 ≤ 0, (subexpression[36] * 0.4 - subexpression[23] * 5.0) - 0.0 ≤ 0, (1.0 / subexpression[34]) * subexpression[37] - 6.14e11 ≤ 0)

# %%
# Solve the optimization problem.
status = optimize!(model)
# Out:
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.6.1.
#
# Number of nonzeros in equality constraint Jacobian...:      204
# Number of nonzeros in inequality constraint Jacobian.:      132
# Number of nonzeros in Lagrangian Hessian.............:     1655
#
# Total number of variables............................:       46
#                      variables with only lower bounds:       45
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       26
# Total number of inequality constraints...............:       13
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       12
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.7000000e-04 2.19e+07 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7159336e-02 2.09e+07 1.02e+00  -1.0 7.78e+03    -  4.89e-02 4.77e-02h  1
#    2 -2.2351923e-01 1.75e+07 3.25e+01  -1.0 8.27e+03    -  6.75e-01 1.77e-01h  1
#    3 -3.8309999e-01 1.49e+07 2.74e+01  -1.0 1.24e+04    -  1.93e-01 1.60e-01h  1
#    4 -6.9590739e-01 1.09e+07 1.65e+01  -1.0 2.37e+04    -  2.02e-01 3.13e-01h  1
#    5 -7.4722711e-01 1.04e+07 2.84e+01  -1.0 3.20e+04    -  1.46e-01 5.15e-02h  1
#    6 -8.2958827e-01 9.55e+06 2.87e+01  -1.0 3.53e+04    -  9.31e-02 8.26e-02h  1
#    7 -8.9009801e-01 8.99e+06 9.98e+02  -1.0 4.80e+04    -  6.60e-01 6.07e-02h  1
#    8 -9.3685528e-01 8.58e+06 2.95e+03  -1.0 1.26e+05    -  3.40e-01 4.69e-02h  1
#    9 -1.1973261e+00 6.61e+06 3.42e+03  -1.0 1.81e+05    -  4.99e-01 2.61e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -1.2026415e+00 6.57e+06 3.84e+03  -1.0 2.24e+05    -  1.15e-01 5.34e-03h  1
#   11 -1.6425629e+00 4.22e+06 1.27e+03  -1.0 2.43e+05    -  1.89e-01 4.42e-01h  1
#   12 -1.7938866e+00 3.63e+06 1.48e+03  -1.0 1.47e+05    -  1.35e-03 1.52e-01f  1
#   13 -2.3601619e+00 2.06e+06 7.82e+03  -1.0 3.10e+05    -  9.99e-02 5.68e-01f  1
#   14 -3.0512214e+00 1.02e+06 1.29e+04  -1.0 1.50e+05    -  1.35e-02 7.01e-01h  1
#   15 -3.6753885e+00 5.36e+05 6.49e+03  -1.0 2.03e+05    -  4.73e-01 6.39e-01h  1
#   16 -4.1186745e+00 3.36e+05 3.49e+03  -1.0 1.94e+05    -  5.53e-02 4.62e-01h  1
#   17 -4.4779827e+00 2.27e+05 2.22e+03  -1.0 3.10e+05    -  5.21e-01 3.82e-01h  1
#   18 -4.9743686e+00 1.30e+05 2.80e+03  -1.0 1.82e+05    -  8.34e-02 5.41e-01f  1
#   19 -5.2844464e+00 9.02e+04 1.86e+03  -1.0 1.69e+05    -  5.25e-01 3.55e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -5.7239101e+00 5.27e+04 5.04e+03  -1.0 1.80e+05    -  2.99e-02 5.19e-01f  1
#   21 -6.3647187e+00 2.40e+04 1.64e+04  -1.0 7.23e+04    -  3.78e-02 7.71e-01f  1
#   22 -6.6741854e+00 1.56e+04 4.86e+04  -1.0 7.08e+01   0.0 1.69e-02 4.18e-01h  1
#   23 -6.6795310e+00 1.55e+04 7.66e+04  -1.0 4.43e+01  -0.5 7.59e-01 8.28e-03h  1
#   24 -7.3237532e+00 4.64e+03 6.50e+04  -1.0 6.46e+01  -1.0 5.77e-01 1.00e+00h  1
#   25 -7.6460810e+00 6.73e+02 1.02e+05  -1.0 1.32e+00  -0.5 9.90e-01 1.00e+00h  1
#   26 -7.7106949e+00 2.46e+01 6.25e+05  -1.0 4.73e-01  -0.1 8.36e-01 1.00e+00f  1
#   27 -7.7128772e+00 6.06e+00 3.02e+00  -1.0 1.46e-01   0.3 1.00e+00 1.00e+00h  1
#   28 -7.7128799e+00 6.93e-01 6.12e+05  -3.8 5.00e-02  -0.2 9.05e-01 1.00e+00h  1
#   29 -7.7128799e+00 7.98e-03 1.32e-02  -3.8 3.58e-03  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -7.7128800e+00 6.80e-04 3.12e-04  -3.8 4.00e-03  -1.1 1.00e+00 1.00e+00h  1
#   31 -7.7128799e+00 1.40e-06 5.75e-04  -5.7 9.05e-04  -1.6 1.00e+00 1.00e+00h  1
#   32 -7.7090615e+00 1.06e+00 1.63e+00  -5.7 7.78e+07    -  3.36e-02 7.46e-03f  1
#   33 -7.6640384e+00 9.68e+02 4.14e+00  -5.7 4.73e+08    -  1.22e-02 9.79e-02h  1
#   34 -7.6641771e+00 9.00e+02 4.45e+02  -5.7 5.26e+02  -2.1 1.00e+00 7.01e-02h  1
#   35 -7.6663045e+00 2.11e+01 6.25e+03  -5.7 4.89e+02  -2.5 7.12e-02 1.00e+00h  1
#   36 -7.6663084e+00 1.93e+01 3.12e+03  -5.7 4.83e-01  -2.1 6.91e-01 5.00e-01h  2
#   37 -7.6663176e+00 4.74e+00 2.20e-02  -5.7 1.68e-01  -1.7 1.00e+00 1.00e+00h  1
#   38 -7.6663186e+00 2.43e-02 3.94e-04  -5.7 5.77e-02  -2.2 1.00e+00 1.00e+00h  1
#   39 -7.6663180e+00 1.50e-03 1.46e-05  -5.7 6.37e-03  -2.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -7.6072171e+00 4.48e+04 5.05e+00  -8.6 1.57e+10    -  3.25e-03 9.98e-02f  1
#   41 -7.6072209e+00 4.47e+04 1.15e+01  -8.6 3.34e+03  -3.1 4.51e-07 7.68e-04h  1
#   42 -7.6087022e+00 3.88e+04 1.48e+03  -8.6 3.34e+03  -3.6 3.31e-03 1.33e-01h  1
#   43 -7.6214375e+00 6.56e+01 2.39e+07  -8.6 2.90e+03  -4.1 2.60e-09 1.00e+00h  1
#   44 -7.6215202e+00 2.74e-03 3.89e+02  -8.6 7.15e-01  -4.5 1.00e+00 1.00e+00h  1
#   45 -7.6214875e+00 4.28e-04 9.09e-03  -8.6 1.17e+00  -5.0 1.00e+00 1.00e+00h  1
#   46 -7.6213896e+00 3.84e-03 1.10e-05  -8.6 3.51e+00  -5.5 1.00e+00 1.00e+00h  1
#   47 -7.6210960e+00 3.46e-02 1.10e-05  -8.6 1.05e+01  -6.0 1.00e+00 1.00e+00h  1
#   48 -7.6202160e+00 3.11e-01 1.10e-05  -8.6 3.16e+01  -6.5 1.00e+00 1.00e+00h  1
#   49 -7.6175830e+00 2.78e+00 1.10e-05  -8.6 9.45e+01  -6.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -7.6173127e+00 2.72e+00 1.20e-02  -8.6 2.82e+02  -7.4 1.00e+00 3.45e-02h  1
#   51 -7.6170888e+00 2.71e+00 2.15e-01  -8.6 8.40e+02  -7.9 1.00e+00 1.01e-02h  1
#   52 -7.6139998e+00 4.34e+02 6.88e-01  -8.6 2.44e+03  -8.4 1.00e+00 5.07e-02h  1
#   53 -7.6132271e+00 4.33e+02 6.58e-01  -8.6 2.15e+03  -8.8 3.19e-01 7.55e-02h  1
#   54 -7.6106015e+00 3.87e+02 5.88e-01  -8.6 5.37e+03  -9.3 1.07e-01 1.05e-01h  1
#   55 -7.6079590e+00 1.86e+02 2.44e-01  -8.6 4.62e+03  -9.8 6.38e-02 5.05e-01h  1
#   56 -7.6066436e+00 1.71e+02 2.38e-01  -8.6 1.22e+04 -10.3 2.31e-01 8.13e-02h  1
#   57 -7.6036481e+00 1.18e+02 2.02e+00  -8.6 1.71e+04 -10.8 5.76e-01 3.13e-01h  1
#   58 -7.5983284e+00 7.13e+01 1.50e+00  -8.6 1.71e+04 -11.2 1.00e+00 6.44e-01h  1
#   59 -7.6002353e+00 6.44e+00 1.69e-01  -8.6 1.42e+04 -11.7 6.88e-01 9.33e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -7.6000589e+00 6.39e+00 6.44e-01  -8.6 3.91e+04 -12.2 1.00e+00 1.85e-01h  3
#   61 -7.5999073e+00 6.13e+00 4.77e-01  -8.6 1.02e+05 -12.7 1.00e+00 5.33e-02h  3
#   62 -7.5997907e+00 6.02e+00 6.84e-01  -8.6 2.24e+05 -13.1 1.00e+00 1.82e-02h  3
#   63 -7.5997029e+00 5.98e+00 1.18e+00  -8.6 3.70e+05 -13.6 1.00e+00 8.25e-03h  3
#   64 -7.5996378e+00 5.93e+00 8.75e-01  -8.6 2.77e+05 -14.1 1.00e+00 8.26e-03h  3
#   65 -7.5751016e+00 7.51e+03 8.43e-01  -8.6 1.74e+10    -  3.57e-02 3.58e-02h  1
#   66 -7.5751016e+00 7.51e+03 8.45e-01  -8.6 8.25e+01  -2.2 3.77e-05 1.32e-05h  1
#   67 -7.5751028e+00 7.51e+03 8.20e-01  -8.6 5.49e+01  -2.7 1.26e-04 6.07e-04h  1
#   68 -7.5751060e+00 7.50e+03 7.92e-01  -8.6 5.49e+01  -3.2 6.20e-04 1.54e-03h  1
#   69 -7.5751175e+00 7.45e+03 7.76e-01  -8.6 5.49e+01  -3.7 2.34e-03 5.62e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -7.5751641e+00 7.32e+03 7.09e-01  -8.6 5.71e+01  -4.2 8.14e-03 1.81e-02h  1
#   71 -7.5754382e+00 6.40e+03 3.96e-01  -8.6 5.43e+01  -4.6 4.23e-02 1.26e-01h  1
#   72 -7.5754515e+00 6.36e+03 6.10e-01  -8.6 4.82e+01  -3.3 3.79e-02 6.56e-03h  1
#   73 -7.5754831e+00 6.26e+03 3.51e+00  -8.6 4.78e+01  -3.8 1.02e-01 1.58e-02h  1
#   74 -7.5775339e+00 2.93e+01 1.54e-01  -8.6 4.72e+01  -4.3 5.55e-06 1.00e+00h  1
#   75 -7.5775447e+00 4.42e+00 2.42e-02  -8.6 4.84e-01  -2.9 9.94e-01 1.00e+00h  1
#   76 -7.5775426e+00 3.63e-01 2.53e-03  -8.6 4.37e-02  -3.4 1.00e+00 1.00e+00h  1
#   77 -7.5775355e+00 1.91e-02 8.54e-05  -8.6 1.34e-01  -3.9 1.00e+00 1.00e+00h  1
#   78 -7.5775329e+00 1.51e-04 1.75e-05  -8.6 5.02e-02  -3.5 1.00e+00 1.00e+00h  1
#   79 -7.5775249e+00 1.34e-02 1.75e-05  -8.6 1.51e-01  -3.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -7.5775009e+00 1.32e-01 1.75e-05  -8.6 4.52e-01  -4.4 1.00e+00 1.00e+00h  1
#   81 -7.5774290e+00 1.16e+00 1.75e-05  -8.6 1.36e+00  -4.9 1.00e+00 1.00e+00h  1
#   82 -7.5772133e+00 5.00e+00 1.75e-05  -8.6 4.07e+00  -5.4 1.00e+00 1.00e+00h  1
#   83 -7.5771804e+00 4.16e+01 3.45e-02  -8.6 1.22e+01  -5.8 1.00e+00 5.10e-02h  1
#   84 -7.5769643e+00 1.46e+02 4.83e-03  -8.6 1.62e+01  -6.3 7.54e-01 1.00e+00h  1
#   85 -7.5769324e+00 4.44e+02 1.09e-02  -8.6 6.15e+00  -5.9 2.69e-01 3.77e-01h  1
#   86 -7.5769333e+00 4.03e+02 2.99e-02  -8.6 1.41e+02  -6.4 2.69e-07 5.40e-03h  1
#   87 -7.5767605e+00 4.45e+02 4.33e-01  -8.6 5.50e+01  -6.8 2.25e-01 2.54e-01h  1
#   88 -7.5767139e+00 6.15e+02 2.25e+00  -8.6 2.08e+01  -6.4 8.98e-02 1.88e-01h  1
#   89 -7.5766704e+00 9.18e+02 1.70e+00  -8.6 3.12e+03  -6.0 8.24e-10 5.62e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -7.5766660e+00 9.13e+02 1.79e+00  -8.6 2.51e+01  -6.5 1.07e-08 5.92e-03h  1
#   91 -7.5765878e+00 8.10e+02 1.15e+00  -8.6 7.03e+01  -7.0 1.22e-03 1.13e-01h  1
#   92 -7.5763567e+00 7.22e+02 1.60e+00  -8.6 2.09e+02  -7.4 1.91e-01 1.08e-01h  1
#   93 -7.5756178e+00 6.41e+02 2.43e+00  -8.6 6.16e+02  -7.9 2.81e-01 1.13e-01h  1
#   94 -7.5758808e+00 7.30e+00 4.24e-05  -8.6 1.94e+01  -8.4 1.00e+00 1.00e+00h  1
#   95 -7.5757963e+00 4.33e+02 1.20e-01  -8.6 1.93e+01  -8.9 1.00e+00 3.47e-01h  1
#   96 -7.5756991e+00 9.19e+02 1.41e-01  -8.6 5.32e+01  -9.3 1.77e-02 2.64e-01h  1
#   97 -7.5756917e+00 1.58e+01 1.78e+00  -8.6 7.49e+02  -9.8 1.42e-08 1.00e+00h  1
#   98 -7.5756646e+00 1.68e-01 1.77e-02  -8.6 3.30e+02 -10.3 9.87e-01 9.88e-01h  1
#   99 -7.5756499e+00 6.04e-02 5.09e-04  -8.6 9.00e+02 -10.8 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100 -7.5755987e+00 4.05e+01 2.03e-04  -8.6 2.64e+03 -11.2 1.00e+00 1.00e+00h  1
#  101 -7.5754711e+00 1.85e+01 7.62e-05  -8.6 7.80e+03 -11.7 1.00e+00 1.00e+00h  1
#  102 -7.5754411e+00 1.26e+07 5.70e-02  -8.6 2.25e+04 -12.2 1.00e+00 8.37e-02h  1
#  103 -7.5729238e+00 1.19e+07 1.75e-02  -8.6 1.71e+10    -  2.29e-05 3.88e-03h  1
#  104 -7.5729238e+00 1.25e+07 5.17e-02  -8.6 4.38e+04 -12.7 3.08e-01 3.27e-05h  1
#  105 -7.5371137e+00 1.17e+07 4.92e-01  -8.6 1.72e+10    -  1.83e-03 5.50e-02h  1
#  106 -7.5371240e+00 1.73e+04 1.95e+00  -8.6 1.31e+05 -13.2 3.78e-01 1.23e-02h  1
#  107 -7.5372223e+00 1.55e+04 1.82e+00  -8.6 2.26e+05 -13.6 8.43e-02 1.03e-01h  1
#  108r-7.5372223e+00 1.55e+04 9.99e+02   3.6 0.00e+00    -  0.00e+00 8.55e-08R  2
#  109r-7.5262781e+00 1.55e+04 9.99e+02   3.6 2.68e+16    -  1.20e-14 1.32e-13f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110r-7.5254405e+00 1.55e+04 2.09e+04   1.5 5.08e+08    -  2.40e-03 1.54e-06f  1
#  111r-1.8305559e-02 3.44e+06 2.91e+04   1.5 8.47e+09    -  3.63e-05 1.13e-03f  1
#  112 -1.7242452e-02 3.44e+06 5.59e+00  -8.6 4.52e+09    -  1.77e-05 8.86e-05h  1
#  113 -1.6904150e-02 3.44e+06 5.57e+00  -8.6 2.47e+09    -  2.41e-04 2.93e-05h  1
#  114 -1.3460561e-02 3.44e+06 5.57e+00  -8.6 3.51e+09    -  2.72e-04 4.86e-04h  1
#  115 -1.0991203e-02 3.44e+06 5.55e+00  -8.6 1.34e+09    -  2.03e-03 7.87e-04h  1
#  116 -1.0643471e-02 3.44e+06 5.49e+00  -8.6 1.95e+08    -  8.18e-04 2.71e-04h  1
#  117 -9.1025698e-03 3.43e+06 5.03e+00  -8.6 3.11e+08    -  6.79e-03 1.11e-03h  1
#  118  4.9880098e-03 3.42e+06 4.64e+00  -8.6 2.41e+09    -  2.31e-04 1.91e-03h  1
#  119  4.5788871e-03 3.42e+06 3.86e+00  -8.6 2.96e+07    -  9.21e-03 1.78e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120 -4.3286702e-03 3.38e+06 3.90e+00  -8.6 1.30e+07    -  2.40e-03 1.11e-02h  1
#  121 -5.8083805e-03 3.37e+06 4.52e+00  -8.6 1.83e+07    -  2.94e-05 3.24e-03h  1
#  122 -7.4350704e-03 3.36e+06 4.48e+00  -8.6 6.81e+06    -  2.98e-03 1.83e-03h  1
#  123 -8.6812799e-03 3.36e+06 4.29e+00  -8.6 4.68e+06    -  3.68e-02 1.29e-03h  4
#  124 -8.9552902e-03 3.36e+06 4.22e+00  -8.6 4.45e+06    -  1.49e-02 2.85e-04h  8
#  125 -9.0511870e-03 3.36e+06 4.21e+00  -8.6 4.46e+06    -  9.13e-04 9.96e-05h 10
#  126 -9.0633747e-03 3.36e+06 3.44e+00  -8.6 4.46e+06    -  1.66e-01 1.27e-05h 13
#  127 -2.0186324e-01 2.75e+06 3.48e+00  -8.6 4.48e+06    -  1.04e-03 2.00e-01h  1
#  128r-2.0186324e-01 2.75e+06 9.99e+02   3.1 0.00e+00  -3.8 0.00e+00 3.00e-07R  2
#  129r-2.0186302e-01 2.75e+06 9.99e+02   3.1 2.61e+12    -  2.52e-09 4.41e-12f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130r-3.1125292e-01 7.04e+09 7.03e+03   1.0 8.10e+08    -  7.59e-03 3.58e-04f  1
#  131r-3.1642511e-01 7.75e+09 7.09e+03   1.0 3.82e+08    -  3.55e-03 9.40e-05f  1
#  132r-8.1920159e-01 6.07e+09 7.32e+03   1.0 3.40e+08    -  3.16e-02 1.20e-02f  1
#  133r-1.4720645e+00 6.09e+09 6.96e+03   1.0 1.75e+07    -  4.06e-02 4.29e-02f  1
#  134r-1.7474926e+00 5.47e+09 7.36e+03   1.0 4.42e+07    -  2.53e-01 5.98e-02f  1
#  135r-1.7579717e+00 5.39e+09 7.69e+03   1.0 1.52e+07    -  9.28e-02 8.16e-03f  1
#  136r-1.8879048e+00 4.10e+09 1.07e+04   1.0 1.84e+07    -  6.06e-01 1.13e-01f  1
#  137r-1.9830078e+00 2.69e+06 1.10e+04   1.0 7.41e+06    -  5.18e-01 9.65e-02f  1
#  138r-2.1401759e+00 2.37e+06 7.78e+03   1.0 1.22e+07    -  3.45e-01 1.56e-01f  1
#  139r-2.1964552e+00 4.37e+09 7.53e+03   1.0 3.42e+06    -  1.16e-01 4.34e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r-2.3167867e+00 1.11e+09 6.53e+03   1.0 1.58e+07    -  2.35e-01 1.23e-01f  1
#  141r-2.3160610e+00 1.08e+09 6.53e+03   1.0 1.41e+04  -4.0 1.63e-02 6.24e-03f  1
#  142r-2.3218241e+00 8.31e+08 6.53e+03   1.0 3.49e+07    -  5.12e-03 7.41e-03f  1
#  143r-2.4102771e+00 1.75e+06 5.62e+03   1.0 1.25e+07    -  1.61e-01 1.16e-01f  1
#  144r-2.4090630e+00 1.73e+06 5.55e+03   1.0 3.01e+04  -4.5 2.25e-03 9.44e-03f  1
#  145r-2.3952796e+00 1.66e+06 5.34e+03   1.0 4.57e+04  -5.0 6.72e-02 4.37e-02f  1
#  146r-2.3947341e+00 1.65e+06 5.32e+03   1.0 5.94e+04  -5.4 1.49e-02 4.34e-03h  1
#  147r-2.3800792e+00 1.51e+06 4.82e+03   1.0 7.63e+04  -5.9 6.10e-02 9.25e-02h  1
#  148r-2.3637057e+00 1.33e+06 4.31e+03   1.0 7.80e+04  -6.4 1.63e-01 1.26e-01h  1
#  149r-2.3365169e+00 1.03e+06 4.08e+03   1.0 1.33e+05  -6.9 5.72e-02 2.70e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r-2.3196361e+00 9.55e+05 3.76e+03   1.0 3.43e+05  -7.3 1.75e-01 7.81e-02h  4
#  151r-2.3187676e+00 9.51e+05 3.74e+03   1.0 3.75e+06  -7.8 5.69e-01 4.86e-03f  3
#  152r-2.2940690e+00 8.59e+05 3.37e+03   1.0 3.76e+05  -7.4 3.42e-01 1.00e-01h  4
#  153r-2.2868439e+00 8.53e+05 3.33e+03   1.0 2.68e+06  -7.9 6.24e-03 6.83e-03f  5
#  154r-2.2647535e+00 7.99e+05 3.07e+03   1.0 4.88e+05  -7.4 2.17e-01 6.63e-02h  4
#  155r-2.0641058e+00 1.69e+05 3.29e+03   1.0 1.65e+05  -7.0 4.24e-01 9.00e-01H  1
#  156r-2.0037265e+00 1.91e+05 1.88e+03   1.0 1.24e+06  -7.5 5.69e-02 7.20e-02f  1
#  157r-2.0010794e+00 1.91e+05 3.94e+03   1.0 2.31e+05  -7.1 1.00e+00 1.99e-02f  1
#  158r-1.9847356e+00 1.89e+05 7.50e+03   1.0 4.79e+05  -7.5 1.00e+00 1.42e-01f  2
#  159r-1.9345370e+00 1.90e+05 2.22e+03   1.0 1.18e+05  -7.1 1.00e+00 8.06e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160r-1.9333276e+00 2.81e+05 7.49e+03   1.0 5.19e+05  -7.6 2.34e-01 3.19e-01f  1
#  161r-1.9247230e+00 2.35e+05 6.24e+03   1.0 1.37e+04  -5.4 1.81e-01 1.61e-01f  1
#  162r-1.9091587e+00 2.04e+05 5.57e+03   1.0 7.12e+04  -5.8 1.52e-01 1.27e-01f  1
#  163r-1.9074714e+00 2.03e+05 5.55e+03   1.0 8.35e+04  -6.3 1.68e-02 3.90e-03h  1
#  164r-1.8351766e+00 2.18e+05 6.87e+03   1.0 2.08e+05  -6.8 8.84e-02 2.42e-01f  1
#  165r-1.8338869e+00 2.13e+05 4.64e+03   1.0 7.39e+04  -6.4 6.01e-01 2.57e-02f  1
#  166r-1.8352173e+00 2.01e+05 4.00e+03   1.0 2.35e+05  -6.8 2.36e-01 1.43e-01f  1
#  167r-1.7896693e+00 2.01e+05 3.25e+03   1.0 2.54e+05  -7.3 1.84e-01 2.26e-01f  1
#  168r-1.7845878e+00 2.01e+05 3.23e+03   1.0 1.06e+06  -7.8 5.76e-03 7.14e-03f  1
#  169r-1.7449904e+00 1.95e+05 3.40e+03   1.0 5.35e+06  -8.3 4.32e-02 1.50e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170r-1.7374644e+00 2.12e+05 3.21e+03   1.0 1.56e+05  -6.9 2.97e-02 5.93e-02f  1
#  171r-1.7238367e+00 6.77e+05 2.33e+03   1.0 4.81e+04  -6.5 2.78e-01 2.93e-01f  1
#  172r-1.6738978e+00 1.89e+06 2.70e+03   1.0 5.97e+05  -7.0 4.46e-02 8.02e-02f  1
#  173r-1.6697094e+00 1.89e+06 2.67e+03   1.0 4.82e+05  -7.5 1.00e+00 1.20e-02f  1
#  174r-1.6292360e+00 1.77e+06 2.72e+03   1.0 1.34e+06  -8.0 1.00e+00 6.16e-02f  1
#  175r-1.5842415e+00 1.61e+06 3.50e+03   1.0 2.73e+06  -8.4 1.00e+00 8.45e-02f  1
#  176r-1.5203632e+00 1.48e+06 3.12e+03   1.0 9.38e+05    -  1.00e+00 1.63e-01f  1
#  177r-1.2374547e+00 9.73e+05 2.91e+03   1.0 8.34e+04    -  1.00e+00 1.00e+00f  1
#  178r-1.2524548e+00 1.07e+06 1.06e+02   1.0 1.58e+04    -  1.00e+00 1.00e+00h  1
#  179r-1.2524548e+00 1.07e+06 9.99e+02   2.0 0.00e+00    -  0.00e+00 3.95e-07R  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180r-1.2387370e+00 1.07e+06 1.00e+03   2.0 1.06e+08    -  1.42e-03 2.37e-05f  1
#  181r-1.2545793e+00 1.09e+06 9.97e+02   1.3 1.26e+06    -  1.35e-01 2.39e-03f  1
#  182 -1.2545720e+00 1.09e+06 2.08e+00  -8.6 9.22e+05    -  3.69e-05 1.48e-04h  1
#  183 -1.2545701e+00 1.09e+06 2.08e+00  -8.6 9.22e+05    -  6.51e-04 3.98e-05h  1
#  184 -1.2544309e+00 1.09e+06 2.07e+00  -8.6 9.22e+05    -  6.38e-03 2.84e-03h  1
#  185r-1.2544309e+00 1.09e+06 9.99e+02   1.2 0.00e+00    -  0.00e+00 3.66e-12R  2
#  186r-1.2561648e+00 1.09e+06 9.99e+02   1.2 3.45e+14    -  3.62e-10 1.79e-11f  3
#  187r-1.2563042e+00 1.09e+06 1.00e+03   1.2 9.94e+08    -  9.70e-04 3.52e-07f  1
#  188r-1.2628421e+00 1.09e+06 9.99e+02   1.2 8.38e+06    -  1.21e-01 7.92e-05f  1
#  189r-1.4108319e+00 1.28e+06 9.37e+02   1.2 5.36e+05    -  2.72e-01 6.13e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r-7.9115575e-01 3.40e+05 6.67e+03   1.2 4.53e+05    -  4.53e-01 3.62e-01f  1
#  191r-8.1406906e-01 3.34e+05 6.25e+03   1.2 8.59e+04    -  1.70e-01 6.28e-02f  1
#  192r-1.0275540e+00 8.24e+05 5.09e+03   1.2 4.17e+06    -  5.92e-04 4.30e-02f  1
#  193r-1.0104213e+00 5.13e+05 1.08e+03   1.2 4.13e+05    -  1.84e-02 4.84e-01h  1
#  194r-1.0300949e+00 5.40e+05 5.69e+02   1.2 1.21e+06    -  4.59e-01 1.36e-01h  1
#  195r-1.1904900e+00 8.37e+05 8.51e+02   1.2 2.31e+05    -  1.65e-01 1.00e+00h  1
#  196r-1.2560592e+00 9.41e+05 2.21e+02   1.2 1.20e+05    -  8.96e-01 6.97e-01f  1
#  197r-1.2808607e+00 1.09e+06 1.59e+02   1.2 2.54e+04    -  1.00e+00 1.00e+00h  1
#  198r-1.2852955e+00 1.12e+06 3.55e+00   1.2 4.34e+03    -  1.00e+00 1.00e+00h  1
#  199r-1.2802287e+00 1.12e+06 2.48e+02  -0.2 4.36e+03    -  1.00e+00 4.78e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200r-1.2746582e+00 1.11e+06 7.81e+01  -0.2 4.03e+03    -  1.00e+00 7.60e-01f  1
#  201r-1.2732736e+00 1.11e+06 2.13e+01  -0.2 4.05e+02    -  1.00e+00 1.00e+00f  1
#  202r-1.2729056e+00 1.11e+06 2.40e+02  -0.9 1.74e+03    -  1.00e+00 4.54e-01f  1
#  203r-1.2725315e+00 1.11e+06 2.51e+01  -0.9 4.49e+02    -  1.00e+00 1.00e+00f  1
#  204r-1.2724646e+00 1.11e+06 5.74e+01  -0.9 5.25e+02    -  1.00e+00 5.60e-01f  1
#  205r-1.2723941e+00 1.11e+06 2.06e+01  -0.9 2.77e+02    -  1.00e+00 1.00e+00f  1
#  206r-1.2723526e+00 1.11e+06 2.90e+01  -0.9 2.46e+02    -  1.00e+00 7.26e-01f  1
#  207r-1.2723219e+00 1.11e+06 1.96e+01  -0.9 1.27e+02    -  1.00e+00 1.00e+00f  1
#  208r-1.2722960e+00 1.11e+06 2.92e+01  -0.9 1.29e+02    -  1.00e+00 8.59e-01h  1
#  209r-1.2722864e+00 1.11e+06 1.23e+01  -0.9 3.93e+01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210r-1.2722754e+00 1.11e+06 5.81e+00  -0.9 4.63e+01    -  1.00e+00 1.00e+00f  1
#  211r-1.2722212e+00 1.11e+06 3.27e+02  -1.6 1.47e+02    -  9.81e-01 4.61e-01f  1
#  212r-1.2721665e+00 1.11e+06 1.69e+01  -1.6 4.08e+01    -  1.00e+00 1.00e+00f  1
#  213r-1.2721696e+00 1.11e+06 3.40e+00  -1.6 9.94e+00    -  1.00e+00 1.00e+00f  1
#  214r-1.2721697e+00 1.11e+06 2.11e-01  -1.6 7.00e-01    -  1.00e+00 1.00e+00f  1
#  215r-1.2721476e+00 1.11e+06 4.97e+00  -3.6 1.33e+01    -  9.88e-01 9.27e-01f  1
#  216r-1.2721469e+00 1.11e+06 3.29e+00  -3.6 6.67e+00    -  6.16e-01 1.00e+00f  1
#  217r-1.2721470e+00 1.11e+06 1.20e-03  -3.6 8.22e-01    -  1.00e+00 1.00e+00h  1
#  218r-1.2721467e+00 1.11e+06 1.93e-01  -5.4 1.28e-01    -  8.12e-01 1.00e+00f  1
#  219r-1.2721515e+00 1.11e+06 4.91e+01  -5.4 5.78e+01    -  2.28e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220r-1.2721515e+00 1.11e+06 5.61e-08  -5.4 3.74e-01    -  1.00e+00 1.00e+00h  1
#  221r-1.2721515e+00 1.11e+06 1.74e+01  -8.1 4.82e-02    -  6.26e-01 8.78e-01f  1
#  222r-1.2722221e+00 1.11e+06 3.10e+02  -8.1 1.41e+03    -  5.05e-02 6.20e-01f  1
#  223r-1.2722422e+00 1.11e+06 2.65e+02  -8.1 5.36e+02    -  9.22e-01 4.63e-01f  1
#  224r-1.2722583e+00 1.11e+06 1.30e+02  -8.1 2.87e+02    -  9.39e-01 6.92e-01f  1
#  225r-1.2722645e+00 1.11e+06 6.03e+01  -8.1 8.85e+01    -  1.00e+00 8.64e-01f  1
#  226r-1.2722655e+00 1.11e+06 1.99e-06  -8.1 1.21e+01    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 226
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2722654532075826e+00   -1.2722654532075826e+00
# Dual infeasibility......:   9.9999895358632784e-01    9.9999895358632784e-01
# Constraint violation....:   1.5703822542070277e+01    1.1099390391702300e+06
# Variable bound violation:   4.0527420800752891e-09    4.0527420800752891e-09
# Complementarity.........:   8.5524245955524111e-09    8.5524245955524111e-09
# Overall NLP error.......:   1.5703822542070277e+01    1.1099390391702300e+06
#
#
# Number of objective function evaluations             = 324
# Number of objective gradient evaluations             = 135
# Number of equality constraint evaluations            = 324
# Number of inequality constraint evaluations          = 324
# Number of equality constraint Jacobian evaluations   = 232
# Number of inequality constraint Jacobian evaluations = 232
# Number of Lagrangian Hessian evaluations             = 227
# Total seconds in IPOPT                               = 0.161
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.

# %%
#Define the values of Fe concentrations that we want to vary
change_ffe_log = 10.0 .^ [-1.0:0.18:log10(5.0);]
change_ffe_nlog = 5.0 .+ [0.0:0.5:5.0;]
change_ffe = append!(change_ffe_log, change_ffe_nlog)
kref_trfFe_range = 0.0 .+ [0.0:5:120.0;]
# Out:
# 25-element Vector{Float64}:
#    0.0
#    5.0
#   10.0
#   15.0
#   20.0
#   25.0
#   30.0
#   35.0
#   40.0
#   45.0
#    ⋮
#   80.0
#   85.0
#   90.0
#   95.0
#  100.0
#  105.0
#  110.0
#  115.0
#  120.0

# %% [markdown]
# Iterate over different environmental conditions and save model output

# %%
# Define empty vectors
s_μ     = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_β     = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrn   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pdin   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pri   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_plb   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pdp   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pp    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pru   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_pld   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pgl   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pre   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pnt   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_psFe   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pfFe   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pnh4   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrnh4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrdop  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrpo4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrsFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ptrfFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pdop   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_pexp   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_porg   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrn   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕdin   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕri   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_ϕlb   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕp    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕru   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_ϕld   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕgl   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕre   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕnt   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕsFe   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrsFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕfFe   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrfFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕnh4   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrnh4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrpo4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕdop   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕtrdop  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕexp   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϕorg   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_cin   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_clm   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_cic   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_cife   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_cip   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ciorg   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Qcell = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Fcell = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Pcell = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Qc    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Qn    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Qf    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_Qp    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vru   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vp    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vgl   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vd    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vre    = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_vlb   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_vld   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vri   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vtrn   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vol   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vnt   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vsFe   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vtrfFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vnh4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vtrpo4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vtrdop  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vexp  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_vorg  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_totp  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_αld   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_D     = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_γTa   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_γTd   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_γTad  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_γTm   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
#s_cli   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_cgu   = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ecost = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ηaan  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ϵ     = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ctag = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_αlm  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_αtag  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_T  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_DIN  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_I  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_kref_trfFe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_ffe  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_nh4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_po4  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
s_sfet  = Array{Float64,2}(undef,length(kref_trfFe_range),length(change_ffe))
# Out:
# 25×21 Matrix{Float64}:
#  2.12708e-314  2.12638e-314  2.12636e-314  …  2.12636e-314  2.12641e-314
#  2.12653e-314  2.12653e-314  2.12707e-314     2.12637e-314  2.12668e-314
#  2.12691e-314  2.12653e-314  2.12651e-314     2.12636e-314  2.12654e-314
#  2.12655e-314  2.12642e-314  2.12638e-314     2.12707e-314  2.12692e-314
#  2.12644e-314  2.12701e-314  2.12641e-314     2.1264e-314   2.12696e-314
#  2.12679e-314  2.12644e-314  2.12636e-314  …  2.12637e-314  2.12691e-314
#  2.12707e-314  2.12706e-314  2.12638e-314     2.12642e-314  2.12668e-314
#  2.12644e-314  2.12641e-314  2.12654e-314     2.12636e-314  2.12662e-314
#  2.12698e-314  2.12641e-314  2.12706e-314     2.12691e-314  2.12636e-314
#  2.12641e-314  2.12649e-314  2.1265e-314      2.12654e-314  2.12642e-314
#  ⋮                                         ⋱                ⋮
#  2.12679e-314  2.12652e-314  2.12638e-314     2.12637e-314  2.12672e-314
#  2.12637e-314  2.1265e-314   2.12684e-314     2.12668e-314  2.1264e-314
#  2.12656e-314  2.12639e-314  2.12637e-314     2.12668e-314  2.12702e-314
#  2.12682e-314  2.12641e-314  2.12644e-314     2.1265e-314   2.12637e-314
#  2.12652e-314  2.12694e-314  2.12707e-314  …  2.12708e-314  2.12689e-314
#  2.12658e-314  2.12639e-314  2.12679e-314     2.12647e-314  2.12639e-314
#  2.12707e-314  2.12654e-314  2.12651e-314     2.12639e-314  2.1268e-314
#  2.12703e-314  2.12638e-314  2.12638e-314     2.12654e-314  2.12671e-314
#  2.12639e-314  2.12642e-314  2.12641e-314     2.12636e-314  2.12636e-314

# %%
# Store model output in empty vectors
for kref_trfFe_value in 1:length(kref_trfFe_range)
    set_value(kref_trfFe, kref_trfFe_range[kref_trfFe_value])
    for ffe_conc in 1:length(change_ffe)
        set_value(ffe, change_ffe[ffe_conc])
        optimize!(model)
        s_μ[kref_trfFe_value,ffe_conc] = exp.(JuMP.value.(logμ))
        #s_β[kref_trfFe_value,ffe_conc]   = JuMP.value.(β)
        s_ptrn[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrn)
        s_pdin[kref_trfFe_value,ffe_conc] = JuMP.value.(pdin)
        s_pri[kref_trfFe_value,ffe_conc] = JuMP.value.(pri)
        #s_plb[kref_trfFe_value,ffe_conc] = JuMP.value.(plb)
        s_pdp[kref_trfFe_value,ffe_conc] = JuMP.value.(pdp)
        s_pp[kref_trfFe_value,ffe_conc]  = JuMP.value.(pp)
        s_pru[kref_trfFe_value,ffe_conc] = JuMP.value.(pru)
        #s_pld[kref_trfFe_value,ffe_conc] = JuMP.value.(pld)
        s_pgl[kref_trfFe_value,ffe_conc] = JuMP.value.(pgl)
        s_pre[kref_trfFe_value,ffe_conc] = JuMP.value.(pre)
        s_pnt[kref_trfFe_value,ffe_conc] = JuMP.value.(pnt)
        s_psFe[kref_trfFe_value,ffe_conc] = JuMP.value.(psFe)
        s_pfFe[kref_trfFe_value,ffe_conc] = JuMP.value.(pfFe)
        s_pnh4[kref_trfFe_value,ffe_conc] = JuMP.value.(pnh4)
        s_ptrnh4[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrnh4)
        s_ptrdop[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrdop)
        s_ptrpo4[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrpo4)
        s_ptrsFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrsFe)
        s_ptrfFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ptrfFe)
        s_pdop[kref_trfFe_value,ffe_conc] = JuMP.value.(pdop)
        s_pexp[kref_trfFe_value,ffe_conc] = JuMP.value.(pexp)
        s_porg[kref_trfFe_value,ffe_conc] = JuMP.value.(porg)
        s_ϕtrn[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrn)
        s_ϕdin[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕdin)
        s_ϕri[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕri)
        #s_ϕlb[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕlb)
        s_ϕp[kref_trfFe_value,ffe_conc]  = JuMP.value.(ϕp)
        s_ϕru[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕru)
        #s_ϕld[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕld)
        s_ϕgl[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕgl)
        s_ϕre[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕre)
        s_ϕnt[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕnt)
        s_ϕsFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕsFe)
        s_ϕtrsFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrsFe)
        s_ϕfFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕfFe)
        s_ϕtrfFe[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrfFe)
        s_ϕnh4[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕnh4)
        s_ϕtrnh4[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrnh4)
        s_ϕtrdop[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrdop)
        s_ϕtrpo4[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕtrpo4)
        s_ϕdop[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕdop)
        s_ϕexp[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕexp)
        s_ϕorg[kref_trfFe_value,ffe_conc] = JuMP.value.(ϕorg)
        s_cin[kref_trfFe_value,ffe_conc] = JuMP.value.(cin)
        s_clm[kref_trfFe_value,ffe_conc] = value(clm)
        s_cic[kref_trfFe_value,ffe_conc]  = JuMP.value.(cic)
        s_cife[kref_trfFe_value,ffe_conc] = JuMP.value.(cife)
        s_cip[kref_trfFe_value,ffe_conc]  = JuMP.value.(cip)
        s_ciorg[kref_trfFe_value,ffe_conc]  = value(ciorg)
        s_Qcell[kref_trfFe_value,ffe_conc] = value(Qcell)
        s_Fcell[kref_trfFe_value,ffe_conc] = value(Fcell)
        s_Pcell[kref_trfFe_value,ffe_conc] = value(Pcell)
        s_Qc[kref_trfFe_value,ffe_conc] = value(Qc)
        s_Qn[kref_trfFe_value,ffe_conc] = value(Qn)
        s_Qf[kref_trfFe_value,ffe_conc] = value(Qf)
        s_Qp[kref_trfFe_value,ffe_conc] = value(Qp)
        s_vru[kref_trfFe_value,ffe_conc]  = value(vru)
        s_vp[kref_trfFe_value,ffe_conc]   = value(vp)
        s_vgl[kref_trfFe_value,ffe_conc]  = value(vgl)
        s_vd[kref_trfFe_value,ffe_conc]   = value(vd)
        s_vre[kref_trfFe_value,ffe_conc]   = value(vre)
        #s_vlb[kref_trfFe_value,ffe_conc] = value(vlb)
        #s_vld[kref_trfFe_value,ffe_conc]  = value(vld)
        s_vri[kref_trfFe_value,ffe_conc]  = value(vri)
        s_vtrn[kref_trfFe_value,ffe_conc]  = value(vtrn)
        s_vol[kref_trfFe_value,ffe_conc]  = value(vol)
        s_vnt[kref_trfFe_value,ffe_conc] = value(vnt)
        s_vsFe[kref_trfFe_value,ffe_conc]  = value(vsFe)
        s_vtrfFe[kref_trfFe_value,ffe_conc]  = value(vtrfFe)
        s_vnh4[kref_trfFe_value,ffe_conc] = value(vnh4)
        s_vtrpo4[kref_trfFe_value,ffe_conc]  = value(vtrpo4)
        s_vtrdop[kref_trfFe_value,ffe_conc]  = value(vtrdop)
        s_vexp[kref_trfFe_value,ffe_conc]  = value(vexp)
        s_vorg[kref_trfFe_value,ffe_conc]  = value(vorg)
        s_totp[kref_trfFe_value,ffe_conc] = value(tot_p)
        #s_αld[kref_trfFe_value,ffe_conc]  = JuMP.value.(αld)
        s_D[kref_trfFe_value,ffe_conc]    = value(D)
        s_γTa[kref_trfFe_value,ffe_conc]  = value(γTa)
        s_γTd[kref_trfFe_value,ffe_conc]  = value(γTd)
        s_γTad[kref_trfFe_value,ffe_conc] = value(γTad)
        s_γTm[kref_trfFe_value,ffe_conc]  = value(γTm)
        #s_cli[kref_trfFe_value,ffe_conc]  = value(cli)
        s_cgu[kref_trfFe_value,ffe_conc]  = value(cgu)
        s_ecost[kref_trfFe_value,ffe_conc] = value(ecost)
        s_ηaan[kref_trfFe_value,ffe_conc]  = value(ηaan)
        s_ϵ[kref_trfFe_value,ffe_conc]    = value(ϵ)
        s_ctag[kref_trfFe_value,ffe_conc]  = JuMP.value.(ctag)
        #s_αlm[kref_trfFe_value,ffe_conc]  = JuMP.value.(αlm)
        #s_αtag[kref_trfFe_value,ffe_conc]  = JuMP.value.(αtag)
        s_T[kref_trfFe_value,ffe_conc] = value(T)
        s_DIN[kref_trfFe_value,ffe_conc] = value(DIN)
        s_I[kref_trfFe_value,ffe_conc] = value(I)
        s_kref_trfFe[kref_trfFe_value,ffe_conc] = value(kref_trfFe_range[kref_trfFe_value])
        s_ffe[kref_trfFe_value,ffe_conc] = value(change_ffe[ffe_conc])
        s_nh4[kref_trfFe_value,ffe_conc] = value(NH4)
        s_po4[kref_trfFe_value,ffe_conc] = value(PO4)
        s_sfet[kref_trfFe_value,ffe_conc] = value(sfet)        
    end
end
# Out:
# Excessive output truncated after 585632 bytes.

# %%
reshape_kref_trfFe = length(kref_trfFe_range)
reshape_ffe = length(change_ffe)
# Out:
# 21

# %%
# Reshape the array into a 1-dimensional array
temp = reshape(s_T .- 273.0, (reshape_kref_trfFe * reshape_ffe, 1))
mu = reshape(s_μ *60*24, (reshape_kref_trfFe * reshape_ffe, 1))
#size = reshape(s_β*3*2, (reshape_kref_trfFe * reshape_ffe, 1))
NC = reshape(s_Qcell, (reshape_kref_trfFe * reshape_ffe, 1))
FC = reshape(s_Fcell, (reshape_kref_trfFe * reshape_ffe, 1)) #Added for Fe:C ratios of the cell
phot = reshape(s_vru, (reshape_kref_trfFe * reshape_ffe, 1))
totp = reshape(s_totp, (reshape_kref_trfFe * reshape_ffe, 1))
chlvol = reshape(s_pp + s_pdp, (reshape_kref_trfFe * reshape_ffe, 1))
#ilpd = reshape(s_ϕld, (reshape_kref_trfFe * reshape_ffe, 1))
icbd = reshape(s_ϕgl, (reshape_kref_trfFe * reshape_ffe, 1))
ichl = reshape(s_ϕp, (reshape_kref_trfFe * reshape_ffe, 1))
icha = reshape(s_ϕre, (reshape_kref_trfFe * reshape_ffe, 1))
itrn = reshape(s_ϕtrn, (reshape_kref_trfFe * reshape_ffe, 1)) #nitrogen transporter proteome
idin = reshape(s_ϕdin, (reshape_kref_trfFe * reshape_ffe, 1)) #DIN proteome
#ilpb = reshape(s_ϕlb, (reshape_kref_trfFe * reshape_ffe, 1))
irib = reshape(s_ϕri, (reshape_kref_trfFe * reshape_ffe, 1))
irub = reshape(s_ϕru, (reshape_kref_trfFe * reshape_ffe, 1))
init = reshape(s_ϕnt, (reshape_kref_trfFe * reshape_ffe, 1)) #added for nitrogenase proteome
isfe = reshape(s_ϕsFe, (reshape_kref_trfFe * reshape_ffe, 1)) #added for siderophore-bound Fe proteome
iffe = reshape(s_ϕfFe, (reshape_kref_trfFe * reshape_ffe, 1)) #added for other Fe proteome
inh4 = reshape(s_ϕnh4, (reshape_kref_trfFe * reshape_ffe, 1)) #added for NH4 proteome
itrnh4 = reshape(s_ϕtrnh4, (reshape_kref_trfFe * reshape_ffe, 1)) #added for NH4 transporter proteome
itrdop = reshape(s_ϕtrdop, (reshape_kref_trfFe * reshape_ffe, 1)) #added for DOP transporter proteome
itrpo4 = reshape(s_ϕtrpo4, (reshape_kref_trfFe * reshape_ffe, 1)) #added for PO4 transporter proteome
itrsfe = reshape(s_ϕtrsFe, (reshape_kref_trfFe * reshape_ffe, 1)) #added for siderophore-bound Fe transporter proteome
itrffe = reshape(s_ϕtrsFe, (reshape_kref_trfFe * reshape_ffe, 1)) #added for other Fe transporter proteome
idop = reshape(s_ϕdop, (reshape_kref_trfFe * reshape_ffe, 1)) #added for DOP proteome
iexp = reshape(s_ϕexp, (reshape_kref_trfFe * reshape_ffe, 1)) #added for export proteome
iorg = reshape(s_ϕorg, (reshape_kref_trfFe * reshape_ffe, 1)) #added for organic molecules synthesis proteome
clip = reshape(s_clm, (reshape_kref_trfFe * reshape_ffe, 1))
ctrn = reshape(s_ptrn, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of nitrogen transporters / um3
cdin = reshape(s_pdin, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of DIN proteins / um3
cp = reshape(s_pp, (reshape_kref_trfFe * reshape_ffe, 1))
cup = reshape(s_pdp, (reshape_kref_trfFe * reshape_ffe, 1))
cri = reshape(s_pri, (reshape_kref_trfFe * reshape_ffe, 1))
cnt = reshape(s_pnt, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of nitrogenase / um3
csfe = reshape(s_psFe, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of siderophore-bound Fe processing proteins / um3
cffe = reshape(s_pfFe, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of other Fe processing proteins / um3
cnh4 = reshape(s_pnh4, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of NH4 processing proteins / um3
ctrnh4 = reshape(s_ptrnh4, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of NH4 transporters / um3
ctrdop = reshape(s_ptrdop, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of DOP transporters / um3
ctrpo4 = reshape(s_ptrpo4, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of PO4 transporters / um3
ctrsFe = reshape(s_ptrsFe, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of siderophore-bound Fe transporters / um3
ctrfFe = reshape(s_ptrfFe, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of other Fe transporters / um3
cdop = reshape(s_pdop, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of DOP processing proteins / um3
cexp = reshape(s_pexp, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of exporter proteins / um3
corg = reshape(s_porg, (reshape_kref_trfFe * reshape_ffe, 1)) # protein: number of proteins for synthesis of organic molecules / um3
#cli = reshape(s_cli, (reshape_kref_trfFe * reshape_ffe, 1))
cgu = reshape(s_cgu, (reshape_kref_trfFe * reshape_ffe, 1))
ctag = reshape(s_ctag, (reshape_kref_trfFe * reshape_ffe, 1))
#ctot = reshape(s_cli * ηlic .+ s_cgu * ηguc .+ s_ctag * ηlic, (a * b * c, 1))
vtrn = reshape(s_vtrn, (reshape_kref_trfFe * reshape_ffe, 1)) # nitrogen transporters reaction rate; atoms of nitrogen/μm3/min
vnt = reshape(s_vnt, (reshape_kref_trfFe * reshape_ffe, 1)) # N2 fixation reaction rate; atoms of nitrogen/μm3/min
vsFe = reshape(s_vsFe, (reshape_kref_trfFe * reshape_ffe, 1)) # siderophore-bound Fe processing rate; atoms of Fe/μm3/min
vtrfFe = reshape(s_vtrfFe, (reshape_kref_trfFe * reshape_ffe, 1)) # other Fe processing rate; atoms of Fe/μm3/min
vnh4 = reshape(s_vnh4, (reshape_kref_trfFe * reshape_ffe, 1)) # NH4 processing rate; molecules of NH4/μm3/min
vtrpo4 = reshape(s_vtrpo4, (reshape_kref_trfFe * reshape_ffe, 1)) # PO4 processing rate; molecules of PO4/μm3/min
vtrdop = reshape(s_vtrdop, (reshape_kref_trfFe * reshape_ffe, 1)) # DOP processing rate; molecules of DOP/μm3/min
vexp = reshape(s_vexp, (reshape_kref_trfFe * reshape_ffe, 1)) # Exporter rate; organic C and N molecules /μm3/min
vorg = reshape(s_vorg, (reshape_kref_trfFe * reshape_ffe, 1)) # Rate of synthesis of organic molecules; organic C and N molecules /μm3/min
ecost = reshape(s_ecost, (reshape_kref_trfFe * reshape_ffe, 1))
Qcell = reshape(s_Qcell, (reshape_kref_trfFe * reshape_ffe, 1))
Fcell = reshape(s_Fcell, (reshape_kref_trfFe * reshape_ffe, 1))
Pcell = reshape(s_Pcell, (reshape_kref_trfFe * reshape_ffe, 1))
Qf = reshape(s_Qf, (reshape_kref_trfFe * reshape_ffe, 1))
Qc = reshape(s_Qc, (reshape_kref_trfFe * reshape_ffe, 1))
Qn = reshape(s_Qn, (reshape_kref_trfFe * reshape_ffe, 1))
Qf = reshape(s_Qf, (reshape_kref_trfFe * reshape_ffe, 1))# total number of atoms of iron/um3
Qp = reshape(s_Qp, (reshape_kref_trfFe * reshape_ffe, 1))# total number of atoms of phosphorus/um3
cic = reshape(s_cic, (reshape_kref_trfFe * reshape_ffe, 1))
cin = reshape(s_cin, (reshape_kref_trfFe * reshape_ffe, 1))
cife = reshape(s_cife, (reshape_kref_trfFe * reshape_ffe, 1)) #Internal iron atoms / um3
cip = reshape(s_cip, (reshape_kref_trfFe * reshape_ffe, 1)) #Internal phosphorus atoms / um3
ciorg = reshape(s_ciorg, (reshape_kref_trfFe * reshape_ffe, 1)) #Internal organic C and N molecules for export / um3
naan= reshape(s_ηaan, (reshape_kref_trfFe * reshape_ffe, 1))
vgl = reshape(s_vgl, (reshape_kref_trfFe * reshape_ffe, 1))
vp = reshape(s_vp, (reshape_kref_trfFe * reshape_ffe, 1))
vre = reshape(s_vre, (reshape_kref_trfFe * reshape_ffe, 1))
vri = reshape(s_vri, (reshape_kref_trfFe * reshape_ffe, 1))
din = reshape(s_DIN, (reshape_kref_trfFe * reshape_ffe, 1))
light = reshape(s_I, (reshape_kref_trfFe * reshape_ffe, 1))
kref_trfFe = reshape(s_kref_trfFe, (reshape_kref_trfFe * reshape_ffe, 1))
ffe = reshape(s_ffe, (reshape_kref_trfFe * reshape_ffe, 1))
nh4 = reshape(s_nh4, (reshape_kref_trfFe * reshape_ffe, 1))
po4 = reshape(s_po4, (reshape_kref_trfFe * reshape_ffe, 1))
sfet = reshape(s_sfet, (reshape_kref_trfFe * reshape_ffe, 1))
# Out:
# 525×1 Matrix{Float64}:
#  1.0
#  9.931001122288901
#  9.930998755118521
#  9.930996199440555
#  9.930993430207895
#  9.92755008862677
#  9.930987142482026
#  9.927547851606787
#  9.930979636443666
#  9.930975296927613
#  ⋮
#  1.0013559796025546
#  1.0037452727394467
#  1.0037457294365393
#  1.00374614782309
#  1.0037465207201093
#  1.0011889496127166
#  1.0037471687260235
#  1.0037474511901632
#  1.0013571484233825

# %%
#Create dataframe
output =  DataFrame(
    "temp" => temp[:], 
    "mu" => mu[:], 
    #"size" => size[:], 
    "NC" => NC[:], 
    "FC" => FC[:],
    "phot" => phot[:], 
    "totp" => totp[:], 
    "chlvol" => chlvol[:], 
    "icbd" => icbd[:], 
    "ichl" => ichl[:], 
    "icha" => icha[:], 
    "itrn" => itrn[:],
    "idin" => idin[:],
    "irib" => irib[:], 
    "irub" => irub[:], 
    "init" => init[:],
    "isfe" => isfe[:],
    "iffe" => iffe[:], 
    "inh4" => inh4[:],
    "itrnh4" => itrnh4[:],
    "itrdop" => itrdop[:],
    "itrpo4" => itrpo4[:],
    "itrsfe" => itrsfe[:],
    "itrffe" => itrffe[:],
    "idop" => idop[:], 
    "iexp" => iexp[:], 
    "iorg" => iorg[:],
    #"ilpb" => ilpb[:],
    "clip" => clip[:], 
    "ctrn" => ctrn[:], 
    "cdin" => cdin[:], 
    "cp" => cp[:], 
    "cup" => cup[:], 
    "cri" => cri[:], 
    "cnt" => cnt[:],
    "csfe" => csfe[:],
    "cffe" => cffe[:], 
    "cnh4" => cnh4[:], 
    "ctrnh4" => ctrnh4[:],
    "ctrdop" => ctrdop[:], 
    "ctrpo4" => ctrpo4[:],
    "ctrsFe" => ctrsFe[:],
    "ctrfFe" => ctrfFe[:],
    "cdop" => cdop[:],  
    "cexp" => cexp[:],
    "corg" => corg[:],  
    "cgu" => cgu[:], 
    "ctag" => ctag[:], 
    "vtrn" => vtrn[:], 
    "vnt" => vnt[:], 
    "vsFe" => vsFe[:],
    "vtrfFe" => vtrfFe[:], 
    "vnh4" => vnh4[:],
    "vtrpo4" => vtrpo4[:],
    "vtrdop" => vtrdop[:],
    "vexp" => vexp[:],
    "vorg" => vorg[:],
    "ecost" => ecost[:],
    "Qcell" => Qcell[:], 
    "Fcell" => Fcell[:], 
    "Pcell" => Pcell[:],
    "Qc" => Qc[:], 
    "Qn" => Qn[:], 
    "Qf" => Qf[:],
    "Qp" => Qp[:],
    "cic" => cic[:], 
    "cin" => cin[:],
    "cife" => cife[:], 
    "cip" => cip[:],
    "ciorg" => ciorg[:],
    "naan" => naan[:], 
    "vgl" => vgl[:],
    "vp" => vp[:], 
    "vre" => vre[:],
    "vri" => vri[:],
    "DIN" => din[:], 
    "light" => light[:],
    "kref_trfFe" => kref_trfFe[:], 
    "ffe" => ffe[:],
    "nh4" => nh4[:],
    "po4" => po4[:],
    "sfet" => sfet[:]
    )
# Out:
# 525×80 DataFrame
#  Row │ temp     mu          NC       FC       phot       totp        chlvol    ⋯
#      │ Float64  Float64     Float64  Float64  Float64    Float64     Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    20.0  403.482     5.71278  7000.0   1.06176e6  1.36135e11  3088.29   ⋯
#    2 │    20.0    0.767064  6.23024  6999.96  3.03656e6  1.54795e11  7058.31
#    3 │    20.0    0.767064  6.23024  6999.96  3.03656e6  1.54795e11  7058.31
#    4 │    20.0    0.767064  6.23024  6999.96  3.03656e6  1.54795e11  7058.31
#    5 │    20.0    0.767064  6.23024  6999.96  3.03656e6  1.54795e11  7058.31   ⋯
#    6 │    20.0    0.767064  6.23024  6999.99  3.03656e6  1.54795e11  7058.32
#    7 │    20.0    0.767064  6.23024  6999.96  3.03656e6  1.54795e11  7058.31
#    8 │    20.0    0.767064  6.23024  6999.99  3.03656e6  1.54795e11  7058.32
#   ⋮  │    ⋮         ⋮          ⋮        ⋮         ⋮          ⋮          ⋮      ⋱
#  519 │    20.0    0.767193  6.22967  6999.94  3.03455e6  1.54773e11  7053.48   ⋯
#  520 │    20.0    0.767195  6.22976  6999.94  3.0349e6   1.54776e11  7054.27
#  521 │    20.0    0.767196  6.22984  6999.94  3.03521e6  1.54779e11  7054.99
#  522 │    20.0    0.767198  6.22992  6999.98  3.03549e6  1.54782e11  7055.65
#  523 │    20.0    0.767199  6.22998  6999.94  3.03574e6  1.54785e11  7056.24   ⋯
#  524 │    20.0    0.7672    6.23005  6999.94  3.03598e6  1.54787e11  7056.78
#  525 │    20.0    0.767201  6.2301   6999.98  3.03619e6  1.54789e11  7057.28
#                                                  73 columns and 510 rows omitted

# %%
#CSV.write("tricho_basic_output.csv", output, header = true)

# %%
#Group dataframe by unique turnover rates of transport of free Fe
df_org_grouped = groupby(output, :kref_trfFe)
# Out:
# GroupedDataFrame with 25 groups based on key: kref_trfFe
# First Group (21 rows): kref_trfFe = 0.0
#  Row │ temp     mu       NC       FC       phot       totp        chlvol   icb ⋯
#      │ Float64  Float64  Float64  Float64  Float64    Float64     Float64  Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    20.0  403.482  5.71278   7000.0  1.06176e6  1.36135e11  3088.29  0.0 ⋯
#    2 │    20.0  403.482  5.71278   7000.0  1.06176e6  1.36135e11  3088.29  0.0
#   ⋮  │    ⋮        ⋮        ⋮        ⋮         ⋮          ⋮          ⋮         ⋱
#   20 │    20.0  403.482  5.71278   7000.0  1.06176e6  1.36135e11  3088.29  0.0
#   21 │    20.0  403.482  5.71278   7000.0  1.06176e6  1.36135e11  3088.29  0.0
#                                                   73 columns and 17 rows omitted
# ⋮
# Last Group (21 rows): kref_trfFe = 120.0
#  Row │ temp     mu         NC       FC       phot         totp        chlvol   ⋯
#      │ Float64  Float64    Float64  Float64  Float64      Float64     Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    20.0  0.767064   6.23024  6999.96   3.03656e6   1.54795e11  7058.31  ⋯
#    2 │    20.0  0.0473597  5.0      6850.99  -1.68911e-6  1.25411e11     1.315
#   ⋮  │    ⋮         ⋮         ⋮        ⋮          ⋮           ⋮           ⋮    ⋱
#   21 │    20.0  0.767201   6.2301   6999.98   3.03619e6   1.54789e11  7057.28
#                                                   74 columns and 18 rows omitted

# %%
df_org_grouped[5]
# Out:
# 21×80 SubDataFrame
#  Row │ temp     mu          NC       FC       phot           totp        chlvo ⋯
#      │ Float64  Float64     Float64  Float64  Float64        Float64     Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058. ⋯
#    2 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058.
#    3 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058.
#    4 │    20.0  0.767064    6.23024  6999.99      3.03656e6  1.54795e11  7058.
#    5 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058. ⋯
#    6 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058.
#    7 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058.
#    8 │    20.0  0.767064    6.23024  6999.96      3.03656e6  1.54795e11  7058.
#   ⋮  │    ⋮         ⋮          ⋮        ⋮           ⋮            ⋮          ⋮  ⋱
#   15 │    20.0  0.767084    6.22359  6999.96      3.01138e6  1.54552e11  6999. ⋯
#   16 │    20.0  0.767085    6.22365  6999.96      3.01162e6  1.54554e11  7000.
#   17 │    20.0  2.67468e-6  5.08819  6986.51  95629.3        1.26913e11   385.
#   18 │    20.0  0.767087    6.22376  6999.96      3.01201e6  1.54558e11  7001.
#   19 │    20.0  0.767088    6.2238   6999.96      3.01217e6  1.5456e11   7001. ⋯
#   20 │    20.0  0.767089    6.22384  6999.96      3.01232e6  1.54561e11  7001.
#   21 │    20.0  0.767089    6.22387  6999.96      3.01245e6  1.54562e11  7002.
#                                                    74 columns and 6 rows omitted

# %%
 #Define a function to get the index for where the switch between siderophore-bound Fe and free Fe occurs
function switch_index(values)
    for (i, value) in enumerate(values)
        if value >= 100
            return i
            
        end
    end
    return length(values)  # If zero is not found
end
# Out:
# switch_index (generic function with 1 method)

# %%
# Initialize empty lists
index_list=[]
conc_switch_list=[]
export_rate_switch_list=[]
kref_trfFe_list=[]
#Loop through dataframes grouped by concentrations of siderophore-bound Fe
for df in df_org_grouped
    #Extract index at which switch happens for speed of free Fe processing machinery
    index_switch = switch_index(df.vtrfFe)
    #Extract the concentration of Fe iron at which the switch happens
    conc_switch = df.ffe[index_switch]
    #Extract the rate of organics export at the switch
    export_rate_switch = df.vexp[1]
    #Extract the turnover rates of transport of free Fe
    kref_trfFe = df.kref_trfFe[index_switch]
    # Append each index and free Fe switch concentration to the lists
    push!(index_list, index_switch)
    push!(conc_switch_list, conc_switch)
    push!(export_rate_switch_list, export_rate_switch)
    push!(kref_trfFe_list, kref_trfFe)
end

# %%
#Create dataframe from lists
df_switch = DataFrame(kref_trfFe = kref_trfFe_list, index_switch = index_list, ffe = conc_switch_list, vexp =export_rate_switch_list)
#Sort
sorted_df = sort(df_switch, :kref_trfFe)
#Remove outliers 
#subset_df = sorted_df[(sorted_df.vexp .> 1) .& (sorted_df.index_switch .> 10), :]
# Out:
# 25×4 DataFrame
#  Row │ kref_trfFe  index_switch  ffe       vexp
#      │ Any         Any           Any       Any
# ─────┼─────────────────────────────────────────────────
#    1 │ 0.0         21            10.0      5.93529e-23
#    2 │ 5.0         21            10.0      8.931
#    3 │ 10.0        21            10.0      8.931
#    4 │ 15.0        21            10.0      8.931
#    5 │ 20.0        10            4.16869   8.93099
#    6 │ 25.0        8             1.8197    8.92755
#    7 │ 30.0        7             1.20226   8.93099
#    8 │ 35.0        7             1.20226   8.92755
#   ⋮  │     ⋮            ⋮           ⋮           ⋮
#   19 │ 90.0        3             0.229087  8.9309
#   20 │ 95.0        3             0.229087  8.93089
#   21 │ 100.0       3             0.229087  8.93087
#   22 │ 105.0       3             0.229087  8.93084
#   23 │ 110.0       3             0.229087  8.93081
#   24 │ 115.0       3             0.229087  8.93078
#   25 │ 120.0       3             0.229087  8.93074
#                                         10 rows omitted

# %%
using PlotlyJS

# %%
plot(layout = (1,2), guidefontsize = 11)

plot!(sorted_df.vexp*60*24, sorted_df.ffe,  color = "#000075", xlabel = "Export rate (organics/um3/day)", ylabel = "[fFe] switch (pM)", linewidth=2, subplot = 1,
xrotation=40, size=(600,480))
scatter!(sorted_df.vexp*60*24, sorted_df.ffe,  color = "#000075", markerstrokewidth=0, subplot = 1, legend=false)
plot!(sorted_df.kref_trfFe, sorted_df.ffe,  color = "#000075", xlabel = "kref_trfFe (atoms Fe/min)", linewidth=2, subplot = 2)
scatter!(sorted_df.kref_trfFe, sorted_df.ffe,  color = "#000075", markerstrokewidth=0, subplot = 2, legend=false)
